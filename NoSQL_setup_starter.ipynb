# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'classDB',
#  'config',
#  'fruits_db',
#  'local',
#  'met',
#  'travel_db',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6584a6198bc4d247f154c6ae'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one(new_restaurant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6584a620dd4f68f20fd8220e'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields

# set query variables
query = {'BusinessTypeID': 1}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

# run query
results = establishments.find(query, fields)

# print a few results
for i in range(4):
    pprint(results[i])
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6584a6198bc4d247f154c6af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6584a6198bc4d247f154c6b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6584a6198bc4d247f154c6b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6584a6198bc4d247f154c6b2')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeI
db.establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set':
        {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
fields = {"BusinessName":1, "BusinessTypeID":1}
results = establishments.find(query,fields)
for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'Penang Flavours',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6584a620dd4f68f20fd8220e')}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"

# set query variables
query = {'LocalAuthorityName': "Dover"}
fields = {'BusinessName': 1}

# run query
results = establishments.find(query, fields)

for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'The Coastguard Inn',
#  '_id': ObjectId('6584a6198bc4d247f154c6ae')}
# {'BusinessName': 'Boodles', '_id': ObjectId('6584a6198bc4d247f154c6af')}
# {'BusinessName': 'The Tea Room', '_id': ObjectId('6584a6198bc4d247f154c6b0')}
# {'BusinessName': 'Refreshment Kiosk',
#  '_id': ObjectId('6584a6198bc4d247f154c6b1')}
# {'BusinessName': 'FirstLight Bar & Café',
#  '_id': ObjectId('6584a6198bc4d247f154c6b2')}
# {'BusinessName': 'The Pines Calyx', '_id': ObjectId('6584a6198bc4d247f154c6b3')}
# {'BusinessName': 'Mrs Knotts Tea Room',
#  '_id': ObjectId('6584a6198bc4d247f154c6b4')}
# {'BusinessName': 'St Margarets At Cliffe Nursery And After School Club',
#  '_id': ObjectId('6584a6198bc4d247f154c6b5')}
# {'BusinessName': 'The Halfway Hut', '_id': ObjectId('6584a6198bc4d247f154c6b6')}
# {'BusinessName': 'The Barn', '_id': ObjectId('6584a6198bc4d247f154c6b7')}
# {'BusinessName': 'Lenox House', '_id': ObjectId('6584a6198bc4d247f154c6b8')}
# {'BusinessName': 'Portal House School',
#  '_id': ObjectId('6584a6198bc4d247f154c6b9')}
# {'BusinessName': 'The White Cliffs',
#  '_id': ObjectId('6584a6198bc4d247f154c6ba')}
# {'BusinessName': 'The Village Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c6bb')}
# {'BusinessName': 'Walmer and Kingsdown Golf Club',
#  '_id': ObjectId('6584a6198bc4d247f154c6bc')}
# {'BusinessName': 'Boat House & Langdon',
#  '_id': ObjectId('6584a6198bc4d247f154c6bd')}
# {'BusinessName': "St Margaret's Bowls and Social Club",
#  '_id': ObjectId('6584a6198bc4d247f154c6be')}
# {'BusinessName': 'St Margarets At Cliffe C P School',
#  '_id': ObjectId('6584a6198bc4d247f154c6bf')}
# {'BusinessName': 'The Lounge Bar', '_id': ObjectId('6584a6198bc4d247f154c6c0')}
# {'BusinessName': 'The Smugglers', '_id': ObjectId('6584a6198bc4d247f154c6c1')}
# {'BusinessName': 'Hogbox', '_id': ObjectId('6584a6198bc4d247f154c6c2')}
# {'BusinessName': 'Rising Sun', '_id': ObjectId('6584a6198bc4d247f154c6c3')}
# {'BusinessName': 'Goodwins Suite (Reception)',
#  '_id': ObjectId('6584a6198bc4d247f154c6c4')}
# {'BusinessName': 'Lovetocater', '_id': ObjectId('6584a6198bc4d247f154c6c5')}
# {'BusinessName': 'Oxtale', '_id': ObjectId('6584a6198bc4d247f154c6c6')}
# {'BusinessName': 'Kingsdown Pre School',
#  '_id': ObjectId('6584a6198bc4d247f154c6c7')}
# {'BusinessName': 'Seahaven & Kingsdown Lodge',
#  '_id': ObjectId('6584a6198bc4d247f154c6c8')}
# {'BusinessName': 'Kingsdown Newsagents',
#  '_id': ObjectId('6584a6198bc4d247f154c6c9')}
# {'BusinessName': 'National Trust White Cliffs',
#  '_id': ObjectId('6584a6198bc4d247f154c6ca')}
# {'BusinessName': 'Zetland Arms', '_id': ObjectId('6584a6198bc4d247f154c6cb')}
# {'BusinessName': 'Kings Head', '_id': ObjectId('6584a6198bc4d247f154c6cc')}
# {'BusinessName': 'Kingsdown And Ringwould Cofe Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c6cd')}
# {'BusinessName': 'Kingsdown & Ringwould Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c6ce')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('6584a6198bc4d247f154c6cf')}
# {'BusinessName': 'Pride of Canterbury',
#  '_id': ObjectId('6584a6198bc4d247f154c6d0')}
# {'BusinessName': 'W H Smiths', '_id': ObjectId('6584a6198bc4d247f154c6d1')}
# {'BusinessName': 'Dover Seaways', '_id': ObjectId('6584a6198bc4d247f154c6d2')}
# {'BusinessName': 'Delft Seaways', '_id': ObjectId('6584a6198bc4d247f154c6d3')}
# {'BusinessName': 'Dunkerque Seaways',
#  '_id': ObjectId('6584a6198bc4d247f154c6d4')}
# {'BusinessName': 'Glendale Lodge', '_id': ObjectId('6584a6198bc4d247f154c6d5')}
# {'BusinessName': 'Pride of Burgundy',
#  '_id': ObjectId('6584a6198bc4d247f154c6d6')}
# {'BusinessName': 'Dover Cargo Terminal',
#  '_id': ObjectId('6584a6198bc4d247f154c6d7')}
# {'BusinessName': 'Adventure Backpackers Hostel',
#  '_id': ObjectId('6584a6198bc4d247f154c6d8')}
# {'BusinessName': 'Pride of Kent', '_id': ObjectId('6584a6198bc4d247f154c6d9')}
# {'BusinessName': 'Spirit of Britain',
#  '_id': ObjectId('6584a6198bc4d247f154c6da')}
# {'BusinessName': 'Spirit of France',
#  '_id': ObjectId('6584a6198bc4d247f154c6db')}
# {'BusinessName': 'Burger King', '_id': ObjectId('6584a6198bc4d247f154c6dc')}
# {'BusinessName': 'Walmer Castle Tea Rooms',
#  '_id': ObjectId('6584a6198bc4d247f154c6dd')}
# {'BusinessName': 'Loddington House Hotel',
#  '_id': ObjectId('6584a6198bc4d247f154c6de')}
# {'BusinessName': 'Cinque Port Arms',
#  '_id': ObjectId('6584a6198bc4d247f154c6df')}
# {'BusinessName': 'The Esplanade Kiosk 1',
#  '_id': ObjectId('6584a6198bc4d247f154c6e0')}
# {'BusinessName': 'Places Leisure', '_id': ObjectId('6584a6198bc4d247f154c6e1')}
# {'BusinessName': 'The Dover Patrol Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c6e2')}
# {'BusinessName': 'Pebbles Kiosk', '_id': ObjectId('6584a6198bc4d247f154c6e3')}
# {'BusinessName': 'Meadowside Day Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c6e4')}
# {'BusinessName': 'GCP Catering Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c6e5')}
# {'BusinessName': 'Riverside Catering Mobile 10',
#  '_id': ObjectId('6584a6198bc4d247f154c6e6')}
# {'BusinessName': 'Table Table at Premier Inn',
#  '_id': ObjectId('6584a6198bc4d247f154c6e7')}
# {'BusinessName': 'Abbeyfield House',
#  '_id': ObjectId('6584a6198bc4d247f154c6e8')}
# {'BusinessName': 'Food Outlets', '_id': ObjectId('6584a6198bc4d247f154c6e9')}
# {'BusinessName': 'Pek on the go Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c6ea')}
# {'BusinessName': 'Port of Dover Cargo Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c6eb')}
# {'BusinessName': 'Cullins Yard', '_id': ObjectId('6584a6198bc4d247f154c6ec')}
# {'BusinessName': 'The Pedaler on the Port',
#  '_id': ObjectId('6584a6198bc4d247f154c6ed')}
# {'BusinessName': 'Royal Cinque Ports Yacht Club',
#  '_id': ObjectId('6584a6198bc4d247f154c6ee')}
# {'BusinessName': 'Dover Marina Hotel',
#  '_id': ObjectId('6584a6198bc4d247f154c6ef')}
# {'BusinessName': "Wheeler's Fish & Chips",
#  '_id': ObjectId('6584a6198bc4d247f154c6f0')}
# {'BusinessName': 'The Walmer Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c6f1')}
# {'BusinessName': "Mr White's English Chophouse (DMHS)",
#  '_id': ObjectId('6584a6198bc4d247f154c6f2')}
# {'BusinessName': 'The Esplanade Kiosk 2',
#  '_id': ObjectId('6584a6198bc4d247f154c6f3')}
# {'BusinessName': 'Costa Coffee, Next',
#  '_id': ObjectId('6584a6198bc4d247f154c6f4')}
# {'BusinessName': 'Boardwalk Cafe', '_id': ObjectId('6584a6198bc4d247f154c6f5')}
# {'BusinessName': 'Hubert House', '_id': ObjectId('6584a6198bc4d247f154c6f6')}
# {'BusinessName': 'Bradfield', '_id': ObjectId('6584a6198bc4d247f154c6f7')}
# {'BusinessName': 'White Horse', '_id': ObjectId('6584a6198bc4d247f154c6f8')}
# {'BusinessName': 'Castle House Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c6f9')}
# {'BusinessName': 'The Booking Hall',
#  '_id': ObjectId('6584a6198bc4d247f154c6fa')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('6584a6198bc4d247f154c6fb')}
# {'BusinessName': 'Burger King', '_id': ObjectId('6584a6198bc4d247f154c6fc')}
# {'BusinessName': 'Kaspas', '_id': ObjectId('6584a6198bc4d247f154c6fd')}
# {'BusinessName': 'Cineworld Cinemas',
#  '_id': ObjectId('6584a6198bc4d247f154c6fe')}
# {'BusinessName': 'The Food Warehouse by Iceland',
#  '_id': ObjectId('6584a6198bc4d247f154c6ff')}
# {'BusinessName': 'Superdrug Stores PLC',
#  '_id': ObjectId('6584a6198bc4d247f154c700')}
# {'BusinessName': 'Taco Bell', '_id': ObjectId('6584a6198bc4d247f154c701')}
# {'BusinessName': 'Nandos', '_id': ObjectId('6584a6198bc4d247f154c702')}
# {'BusinessName': 'Greggs', '_id': ObjectId('6584a6198bc4d247f154c703')}
# {'BusinessName': 'Marks and Spencer Dover Simply Food',
#  '_id': ObjectId('6584a6198bc4d247f154c704')}
# {'BusinessName': 'Cinnamon Island', '_id': ObjectId('6584a6198bc4d247f154c705')}
# {'BusinessName': 'Travelodge', '_id': ObjectId('6584a6198bc4d247f154c706')}
# {'BusinessName': 'Rico Sabor', '_id': ObjectId('6584a6198bc4d247f154c707')}
# {'BusinessName': 'Poundland', '_id': ObjectId('6584a6198bc4d247f154c708')}
# {'BusinessName': 'St Anselms Nursing Home',
#  '_id': ObjectId('6584a6198bc4d247f154c709')}
# {'BusinessName': 'Cleveland Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c70a')}
# {'BusinessName': 'Principals by CH&Co Group ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c70b')}
# {'BusinessName': 'B 4 9 Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c70c')}
# {'BusinessName': 'Emmaus Dover Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c70d')}
# {'BusinessName': 'Holland and Barrett',
#  '_id': ObjectId('6584a6198bc4d247f154c70e')}
# {'BusinessName': 'German Doner Kebab',
#  '_id': ObjectId('6584a6198bc4d247f154c70f')}
# {'BusinessName': 'IL RUSTICO', '_id': ObjectId('6584a6198bc4d247f154c710')}
# {'BusinessName': 'The Hoptimist Taproom and Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c711')}
# {'BusinessName': 'The Duchess', '_id': ObjectId('6584a6198bc4d247f154c712')}
# {'BusinessName': 'Number One Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c713')}
# {'BusinessName': 'Funky Monkey', '_id': ObjectId('6584a6198bc4d247f154c714')}
# {'BusinessName': 'Castle Inn', '_id': ObjectId('6584a6198bc4d247f154c715')}
# {'BusinessName': 'The Lord Nelson', '_id': ObjectId('6584a6198bc4d247f154c716')}
# {'BusinessName': 'Trinity Homes', '_id': ObjectId('6584a6198bc4d247f154c717')}
# {'BusinessName': "Rhino & Bull's", '_id': ObjectId('6584a6198bc4d247f154c718')}
# {'BusinessName': 'Aspendos', '_id': ObjectId('6584a6198bc4d247f154c719')}
# {'BusinessName': 'Rippledown House Environmental Educ',
#  '_id': ObjectId('6584a6198bc4d247f154c71a')}
# {'BusinessName': 'Terrace Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c71b')}
# {'BusinessName': 'Dover kebab house',
#  '_id': ObjectId('6584a6198bc4d247f154c71c')}
# {'BusinessName': 'Blakes of Dover', '_id': ObjectId('6584a6198bc4d247f154c71d')}
# {'BusinessName': 'Modern Moon Mini Mart',
#  '_id': ObjectId('6584a6198bc4d247f154c71e')}
# {'BusinessName': 'Dinos Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c71f')}
# {'BusinessName': 'Castle Take Away Foods',
#  '_id': ObjectId('6584a6198bc4d247f154c720')}
# {'BusinessName': 'Generals Meadow Nursing Home',
#  '_id': ObjectId('6584a6198bc4d247f154c721')}
# {'BusinessName': 'KFC', '_id': ObjectId('6584a6198bc4d247f154c722')}
# {'BusinessName': 'Xpresso Cafe', '_id': ObjectId('6584a6198bc4d247f154c723')}
# {'BusinessName': 'Market Square Foods Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c724')}
# {'BusinessName': 'Londis', '_id': ObjectId('6584a6198bc4d247f154c725')}
# {'BusinessName': 'Cafe Gusto', '_id': ObjectId('6584a6198bc4d247f154c726')}
# {'BusinessName': 'Sunrise Cafe', '_id': ObjectId('6584a6198bc4d247f154c727')}
# {'BusinessName': 'Oriental Minimart',
#  '_id': ObjectId('6584a6198bc4d247f154c728')}
# {'BusinessName': 'The Elephant & Hind',
#  '_id': ObjectId('6584a6198bc4d247f154c729')}
# {'BusinessName': 'Orient Noodle Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c72a')}
# {'BusinessName': 'BP/Budgens Dover South',
#  '_id': ObjectId('6584a6198bc4d247f154c72b')}
# {'BusinessName': 'Swingate Inn', '_id': ObjectId('6584a6198bc4d247f154c72c')}
# {'BusinessName': 'Dover Masonic Hall',
#  '_id': ObjectId('6584a6198bc4d247f154c72d')}
# {'BusinessName': 'MK Catering', '_id': ObjectId('6584a6198bc4d247f154c72e')}
# {'BusinessName': 'Bluebirds', '_id': ObjectId('6584a6198bc4d247f154c72f')}
# {'BusinessName': 'Pizza 2 Night', '_id': ObjectId('6584a6198bc4d247f154c730')}
# {'BusinessName': 'Happy Chef', '_id': ObjectId('6584a6198bc4d247f154c731')}
# {'BusinessName': 'Istanbul Kebab House',
#  '_id': ObjectId('6584a6198bc4d247f154c732')}
# {'BusinessName': 'THENU Convenience Store',
#  '_id': ObjectId('6584a6198bc4d247f154c733')}
# {'BusinessName': 'Laureston House', '_id': ObjectId('6584a6198bc4d247f154c734')}
# {'BusinessName': 'Greggs', '_id': ObjectId('6584a6198bc4d247f154c735')}
# {'BusinessName': 'The Shake Shop & The Hot Dog Hut',
#  '_id': ObjectId('6584a6198bc4d247f154c736')}
# {'BusinessName': 'Sonia Lodge', '_id': ObjectId('6584a6198bc4d247f154c737')}
# {'BusinessName': 'The Attic Bar', '_id': ObjectId('6584a6198bc4d247f154c738')}
# {'BusinessName': 'Honey Pot Cafe', '_id': ObjectId('6584a6198bc4d247f154c739')}
# {'BusinessName': 'Roman Quay', '_id': ObjectId('6584a6198bc4d247f154c73a')}
# {'BusinessName': 'The Market Square Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c73b')}
# {'BusinessName': 'Chaplins', '_id': ObjectId('6584a6198bc4d247f154c73c')}
# {'BusinessName': 'Pizza Shack', '_id': ObjectId('6584a6198bc4d247f154c73d')}
# {'BusinessName': 'Dover Convenience Store',
#  '_id': ObjectId('6584a6198bc4d247f154c73e')}
# {'BusinessName': 'Walmer Court Farm Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c73f')}
# {'BusinessName': 'Discovery Nursery',
#  '_id': ObjectId('6584a6198bc4d247f154c740')}
# {'BusinessName': 'St Marys Parish Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c741')}
# {'BusinessName': 'Five Bells Inn', '_id': ObjectId('6584a6198bc4d247f154c742')}
# {'BusinessName': 'Vinoteq Wine Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c743')}
# {'BusinessName': 'Super Pizza', '_id': ObjectId('6584a6198bc4d247f154c744')}
# {'BusinessName': 'The Drum Major', '_id': ObjectId('6584a6198bc4d247f154c745')}
# {'BusinessName': 'Best Kebab', '_id': ObjectId('6584a6198bc4d247f154c746')}
# {'BusinessName': 'Subway', '_id': ObjectId('6584a6198bc4d247f154c747')}
# {'BusinessName': 'Crystal Garden', '_id': ObjectId('6584a6198bc4d247f154c748')}
# {'BusinessName': 'Saffron', '_id': ObjectId('6584a6198bc4d247f154c749')}
# {'BusinessName': 'Eight Bells PH', '_id': ObjectId('6584a6198bc4d247f154c74a')}
# {'BusinessName': 'La Salle Verte', '_id': ObjectId('6584a6198bc4d247f154c74b')}
# {'BusinessName': 'Cafe Melange', '_id': ObjectId('6584a6198bc4d247f154c74c')}
# {'BusinessName': 'The Corner Cafe', '_id': ObjectId('6584a6198bc4d247f154c74d')}
# {'BusinessName': 'Five A Day', '_id': ObjectId('6584a6198bc4d247f154c74e')}
# {'BusinessName': 'Baptist Church', '_id': ObjectId('6584a6198bc4d247f154c74f')}
# {'BusinessName': 'The Knoll Nursing Home/Ami Court',
#  '_id': ObjectId('6584a6198bc4d247f154c750')}
# {'BusinessName': 'MFG ESSO WALMER', '_id': ObjectId('6584a6198bc4d247f154c751')}
# {'BusinessName': 'Walmer Esso', '_id': ObjectId('6584a6198bc4d247f154c752')}
# {'BusinessName': 'European Mini Mart',
#  '_id': ObjectId('6584a6198bc4d247f154c753')}
# {'BusinessName': 'Sunnycroft Bed & Breakfast',
#  '_id': ObjectId('6584a6198bc4d247f154c754')}
# {'BusinessName': 'Downs Sailing Club',
#  '_id': ObjectId('6584a6198bc4d247f154c755')}
# {'BusinessName': 'Tummy Station', '_id': ObjectId('6584a6198bc4d247f154c756')}
# {'BusinessName': 'Lava Lounge Bar', '_id': ObjectId('6584a6198bc4d247f154c757')}
# {'BusinessName': 'Walmer Baptist Church',
#  '_id': ObjectId('6584a6198bc4d247f154c758')}
# {'BusinessName': 'Buzz Bingo', '_id': ObjectId('6584a6198bc4d247f154c759')}
# {'BusinessName': 'The Duke Of Yorks Brewers Fayre',
#  '_id': ObjectId('6584a6198bc4d247f154c75a')}
# {'BusinessName': "Stanley's bar & coffee lounge ltd",
#  '_id': ObjectId('6584a6198bc4d247f154c75b')}
# {'BusinessName': 'Wale & Son', '_id': ObjectId('6584a6198bc4d247f154c75c')}
# {'BusinessName': 'B&M Store', '_id': ObjectId('6584a6198bc4d247f154c75d')}
# {'BusinessName': 'Merkur Slots', '_id': ObjectId('6584a6198bc4d247f154c75e')}
# {'BusinessName': 'Biggin Off Licence',
#  '_id': ObjectId('6584a6198bc4d247f154c75f')}
# {'BusinessName': 'Oddfellows Cinque Ports Warden',
#  '_id': ObjectId('6584a6198bc4d247f154c760')}
# {'BusinessName': 'Sea Cafe Coffee Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c761')}
# {'BusinessName': 'Londis (Town & Country Store)',
#  '_id': ObjectId('6584a6198bc4d247f154c762')}
# {'BusinessName': 'The Stag', '_id': ObjectId('6584a6198bc4d247f154c763')}
# {'BusinessName': 'Burgoyne Heights Pre-School',
#  '_id': ObjectId('6584a6198bc4d247f154c764')}
# {'BusinessName': 'Everest Store', '_id': ObjectId('6584a6198bc4d247f154c765')}
# {'BusinessName': 'The Castle Fish Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c766')}
# {'BusinessName': 'D Gilliver Newsagents',
#  '_id': ObjectId('6584a6198bc4d247f154c767')}
# {'BusinessName': 'The Freed Man', '_id': ObjectId('6584a6198bc4d247f154c768')}
# {'BusinessName': "Jane's", '_id': ObjectId('6584a6198bc4d247f154c769')}
# {'BusinessName': 'The Haymans Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c76a')}
# {'BusinessName': 'Walmer News', '_id': ObjectId('6584a6198bc4d247f154c76b')}
# {'BusinessName': 'News in', '_id': ObjectId('6584a6198bc4d247f154c76c')}
# {'BusinessName': "Goodchild's of Walmer",
#  '_id': ObjectId('6584a6198bc4d247f154c76d')}
# {'BusinessName': 'The Thompsons Bell',
#  '_id': ObjectId('6584a6198bc4d247f154c76e')}
# {'BusinessName': 'Poundland', '_id': ObjectId('6584a6198bc4d247f154c76f')}
# {'BusinessName': "Macari's", '_id': ObjectId('6584a6198bc4d247f154c770')}
# {'BusinessName': 'Dover Soup Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c771')}
# {'BusinessName': 'The Beano Cafe', '_id': ObjectId('6584a6198bc4d247f154c772')}
# {'BusinessName': 'Boots UK Ltd', '_id': ObjectId('6584a6198bc4d247f154c773')}
# {'BusinessName': 'The Weigh Inn', '_id': ObjectId('6584a6198bc4d247f154c774')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('6584a6198bc4d247f154c775')}
# {'BusinessName': 'New China Town', '_id': ObjectId('6584a6198bc4d247f154c776')}
# {'BusinessName': 'Brunch Cafe Limited',
#  '_id': ObjectId('6584a6198bc4d247f154c777')}
# {'BusinessName': 'Save On', '_id': ObjectId('6584a6198bc4d247f154c778')}
# {'BusinessName': "Amarillo's", '_id': ObjectId('6584a6198bc4d247f154c779')}
# {'BusinessName': 'Maison Dieu Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c77a')}
# {'BusinessName': 'Dover International',
#  '_id': ObjectId('6584a6198bc4d247f154c77b')}
# {'BusinessName': 'Favorite Chicken & Ribs',
#  '_id': ObjectId('6584a6198bc4d247f154c77c')}
# {'BusinessName': "Domino's Pizza", '_id': ObjectId('6584a6198bc4d247f154c77d')}
# {'BusinessName': 'Bandstand Bakery',
#  '_id': ObjectId('6584a6198bc4d247f154c77e')}
# {'BusinessName': 'Royal Marines Association',
#  '_id': ObjectId('6584a6198bc4d247f154c77f')}
# {'BusinessName': 'Maison Dieu Nursery School',
#  '_id': ObjectId('6584a6198bc4d247f154c780')}
# {'BusinessName': 'Dover Post Office',
#  '_id': ObjectId('6584a6198bc4d247f154c781')}
# {'BusinessName': 'Dovorian', '_id': ObjectId('6584a6198bc4d247f154c782')}
# {'BusinessName': 'Golden Lion', '_id': ObjectId('6584a6198bc4d247f154c783')}
# {'BusinessName': 'Walmer Fish & Chips',
#  '_id': ObjectId('6584a6198bc4d247f154c784')}
# {'BusinessName': 'Savers', '_id': ObjectId('6584a6198bc4d247f154c785')}
# {'BusinessName': 'The Lighthouse', '_id': ObjectId('6584a6198bc4d247f154c786')}
# {'BusinessName': "Rose's Handmade Cakes",
#  '_id': ObjectId('6584a6198bc4d247f154c787')}
# {'BusinessName': 'Shell Budgens Dover',
#  '_id': ObjectId('6584a6198bc4d247f154c788')}
# {'BusinessName': 'Pomegranate Pantry and Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c789')}
# {'BusinessName': 'Goose on the Green',
#  '_id': ObjectId('6584a6198bc4d247f154c78a')}
# {'BusinessName': 'Bee Crafty Bee Happy',
#  '_id': ObjectId('6584a6198bc4d247f154c78b')}
# {'BusinessName': 'Age Concern - Dover',
#  '_id': ObjectId('6584a6198bc4d247f154c78c')}
# {'BusinessName': 'The Berry', '_id': ObjectId('6584a6198bc4d247f154c78d')}
# {'BusinessName': 'Dover Bowling Club',
#  '_id': ObjectId('6584a6198bc4d247f154c78e')}
# {'BusinessName': 'The Well Resource Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c78f')}
# {'BusinessName': 'Bengal Spice', '_id': ObjectId('6584a6198bc4d247f154c790')}
# {'BusinessName': 'Deal & Betteshanger  Rugby Club',
#  '_id': ObjectId('6584a6198bc4d247f154c791')}
# {'BusinessName': 'Palace Fish Bar', '_id': ObjectId('6584a6198bc4d247f154c792')}
# {'BusinessName': 'Gamebase', '_id': ObjectId('6584a6198bc4d247f154c793')}
# {'BusinessName': 'Dover Sea Angling Club',
#  '_id': ObjectId('6584a6198bc4d247f154c794')}
# {'BusinessName': 'Walmer Chapel', '_id': ObjectId('6584a6198bc4d247f154c795')}
# {'BusinessName': 'Peckish', '_id': ObjectId('6584a6198bc4d247f154c796')}
# {'BusinessName': 'OAKLEYS', '_id': ObjectId('6584a6198bc4d247f154c797')}
# {'BusinessName': 'Remskeys', '_id': ObjectId('6584a6198bc4d247f154c798')}
# {'BusinessName': 'Rotherwood Butchers',
#  '_id': ObjectId('6584a6198bc4d247f154c799')}
# {'BusinessName': 'Doyrms Coffee Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c79a')}
# {'BusinessName': 'Greggs Bakers', '_id': ObjectId('6584a6198bc4d247f154c79b')}
# {'BusinessName': 'St Albans Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c79c')}
# {'BusinessName': 'Connaught Hotel', '_id': ObjectId('6584a6198bc4d247f154c79d')}
# {'BusinessName': 'St.Edmonds', '_id': ObjectId('6584a6198bc4d247f154c79e')}
# {'BusinessName': 'Hotel Alma & Cafe Express',
#  '_id': ObjectId('6584a6198bc4d247f154c79f')}
# {'BusinessName': "Dover's Restover Guest House",
#  '_id': ObjectId('6584a6198bc4d247f154c7a0')}
# {'BusinessName': 'Thong Dees Thai', '_id': ObjectId('6584a6198bc4d247f154c7a1')}
# {'BusinessName': 'MFG BP Priory Service Station',
#  '_id': ObjectId('6584a6198bc4d247f154c7a2')}
# {'BusinessName': 'Walmer Care Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c7a3')}
# {'BusinessName': 'Prince Albert Public House',
#  '_id': ObjectId('6584a6198bc4d247f154c7a4')}
# {'BusinessName': 'Priory Service Station',
#  '_id': ObjectId('6584a6198bc4d247f154c7a5')}
# {'BusinessName': 'St Stephens Residential Home',
#  '_id': ObjectId('6584a6198bc4d247f154c7a6')}
# {'BusinessName': 'Dover College', '_id': ObjectId('6584a6198bc4d247f154c7a7')}
# {'BusinessName': 'The Academy Dover',
#  '_id': ObjectId('6584a6198bc4d247f154c7a8')}
# {'BusinessName': 'Dover Town Hall', '_id': ObjectId('6584a6198bc4d247f154c7a9')}
# {'BusinessName': 'Aycliffe Food & Wine',
#  '_id': ObjectId('6584a6198bc4d247f154c7aa')}
# {'BusinessName': 'The Malvern Hotel',
#  '_id': ObjectId('6584a6198bc4d247f154c7ab')}
# {'BusinessName': 'Norman Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c7ac')}
# {'BusinessName': 'Fish Bar & Grill',
#  '_id': ObjectId('6584a6198bc4d247f154c7ad')}
# {'BusinessName': 'La Scala', '_id': ObjectId('6584a6198bc4d247f154c7ae')}
# {'BusinessName': 'Key Stores', '_id': ObjectId('6584a6198bc4d247f154c7af')}
# {'BusinessName': 'Whitecliffs Cafe',
#  '_id': ObjectId('6584a6198bc4d247f154c7b0')}
# {'BusinessName': 'Wellingtons', '_id': ObjectId('6584a6198bc4d247f154c7b1')}
# {'BusinessName': 'The Park', '_id': ObjectId('6584a6198bc4d247f154c7b2')}
# {'BusinessName': 'The Fleurs', '_id': ObjectId('6584a6198bc4d247f154c7b3')}
# {'BusinessName': 'Pizza Pronto', '_id': ObjectId('6584a6198bc4d247f154c7b4')}
# {'BusinessName': 'Brambles Nursery',
#  '_id': ObjectId('6584a6198bc4d247f154c7b5')}
# {'BusinessName': 'The Downs C Of E Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c7b6')}
# {'BusinessName': 'Red House', '_id': ObjectId('6584a6198bc4d247f154c7b7')}
# {'BusinessName': 'St Richards School Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c7b8')}
# {'BusinessName': 'St Richards Roman Catholic Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c7b9')}
# {'BusinessName': 'Turkish BBQ & Marina Mexican',
#  '_id': ObjectId('6584a6198bc4d247f154c7ba')}
# {'BusinessName': 'Deal Parochial C Of E Aided Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c7bb')}
# {'BusinessName': 'Dover Fish Bar', '_id': ObjectId('6584a6198bc4d247f154c7bc')}
# {'BusinessName': 'Salisbury House B & B',
#  '_id': ObjectId('6584a6198bc4d247f154c7bd')}
# {'BusinessName': 'Calcutta Port', '_id': ObjectId('6584a6198bc4d247f154c7be')}
# {'BusinessName': 'Dover Baptist Church',
#  '_id': ObjectId('6584a6198bc4d247f154c7bf')}
# {'BusinessName': 'Deal Parochial', '_id': ObjectId('6584a6198bc4d247f154c7c0')}
# {'BusinessName': 'Momo Hub limited',
#  '_id': ObjectId('6584a6198bc4d247f154c7c1')}
# {'BusinessName': 'Turkish Delight', '_id': ObjectId('6584a6198bc4d247f154c7c2')}
# {'BusinessName': 'Saveon Supermarket',
#  '_id': ObjectId('6584a6198bc4d247f154c7c3')}
# {'BusinessName': 'Dover Food & Wine',
#  '_id': ObjectId('6584a6198bc4d247f154c7c4')}
# {'BusinessName': 'Buffers', '_id': ObjectId('6584a6198bc4d247f154c7c5')}
# {'BusinessName': 'Priory Hotel', '_id': ObjectId('6584a6198bc4d247f154c7c6')}
# {'BusinessName': 'Guston Church Of England Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c7c7')}
# {'BusinessName': 'Homeleigh Residential Care',
#  '_id': ObjectId('6584a6198bc4d247f154c7c8')}
# {'BusinessName': 'The Courtyard Oyster Bar And Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c7c9')}
# {'BusinessName': 'U Babuni', '_id': ObjectId('6584a6198bc4d247f154c7ca')}
# {'BusinessName': 'New Moonflower', '_id': ObjectId('6584a6198bc4d247f154c7cb')}
# {'BusinessName': 'English Heritage Trust',
#  '_id': ObjectId('6584a6198bc4d247f154c7cc')}
# {'BusinessName': 'Baba Food and Wine',
#  '_id': ObjectId('6584a6198bc4d247f154c7cd')}
# {'BusinessName': 'Euro Chicken', '_id': ObjectId('6584a6198bc4d247f154c7ce')}
# {'BusinessName': "Bleriot's House", '_id': ObjectId('6584a6198bc4d247f154c7cf')}
# {'BusinessName': 'Pumpkin Cafe Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c7d0')}
# {'BusinessName': 'The Flamin Chicken',
#  '_id': ObjectId('6584a6198bc4d247f154c7d1')}
# {'BusinessName': "Sally Reeve's Cambridge Weight Plan",
#  '_id': ObjectId('6584a6198bc4d247f154c7d2')}
# {'BusinessName': 'The Port Arms', '_id': ObjectId('6584a6198bc4d247f154c7d3')}
# {'BusinessName': 'Community Church Deal',
#  '_id': ObjectId('6584a6198bc4d247f154c7d4')}
# {'BusinessName': 'Dunkerleys Hotel & Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c7d5')}
# {'BusinessName': 'Zazen Kitchen', '_id': ObjectId('6584a6198bc4d247f154c7d6')}
# {'BusinessName': 'Number One B & B',
#  '_id': ObjectId('6584a6198bc4d247f154c7d7')}
# {'BusinessName': 'Duke of Yorks Royal Military School',
#  '_id': ObjectId('6584a6198bc4d247f154c7d8')}
# {'BusinessName': 'The Blue Mermaid Fish Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c7d9')}
# {'BusinessName': 'HEY! Sushi', '_id': ObjectId('6584a6198bc4d247f154c7da')}
# {'BusinessName': 'Golden Grill Fish Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c7db')}
# {'BusinessName': 'Walmer Castle', '_id': ObjectId('6584a6198bc4d247f154c7dc')}
# {'BusinessName': 'Kings Head', '_id': ObjectId('6584a6198bc4d247f154c7dd')}
# {'BusinessName': 'The Taphouse', '_id': ObjectId('6584a6198bc4d247f154c7de')}
# {'BusinessName': 'The Village Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c7df')}
# {'BusinessName': 'Icy hog parlour', '_id': ObjectId('6584a6198bc4d247f154c7e0')}
# {'BusinessName': 'White Cliffs Convenience Store',
#  '_id': ObjectId('6584a6198bc4d247f154c7e1')}
# {'BusinessName': 'Marmaris Kebab & Pizza House',
#  '_id': ObjectId('6584a6198bc4d247f154c7e2')}
# {'BusinessName': 'MJ Stores', '_id': ObjectId('6584a6198bc4d247f154c7e3')}
# {'BusinessName': 'Chicken King', '_id': ObjectId('6584a6198bc4d247f154c7e4')}
# {'BusinessName': 'Dylan Palace', '_id': ObjectId('6584a6198bc4d247f154c7e5')}
# {'BusinessName': 'Deal Beach Hut', '_id': ObjectId('6584a6198bc4d247f154c7e6')}
# {'BusinessName': 'Hey Hey', '_id': ObjectId('6584a6198bc4d247f154c7e7')}
# {'BusinessName': "Hoody's Community Cafe",
#  '_id': ObjectId('6584a6198bc4d247f154c7e8')}
# {'BusinessName': 'Hoodys Community Cafe',
#  '_id': ObjectId('6584a6198bc4d247f154c7e9')}
# {'BusinessName': 'Deal Pier Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c7ea')}
# {'BusinessName': 'International Store',
#  '_id': ObjectId('6584a6198bc4d247f154c7eb')}
# {'BusinessName': 'Deal Victoria And Barnes Close Cc',
#  '_id': ObjectId('6584a6198bc4d247f154c7ec')}
# {'BusinessName': 'Dover Pantry', '_id': ObjectId('6584a6198bc4d247f154c7ed')}
# {'BusinessName': 'Hog & Bean Deli and Eatery',
#  '_id': ObjectId('6584a6198bc4d247f154c7ee')}
# {'BusinessName': 'Little Harriettes of Deal',
#  '_id': ObjectId('6584a6198bc4d247f154c7ef')}
# {'BusinessName': 'Lillyroos', '_id': ObjectId('6584a6198bc4d247f154c7f0')}
# {'BusinessName': 'Cin Cin', '_id': ObjectId('6584a6198bc4d247f154c7f1')}
# {'BusinessName': 'Pop Up Cafe', '_id': ObjectId('6584a6198bc4d247f154c7f2')}
# {'BusinessName': 'Tastier Treats', '_id': ObjectId('6584a6198bc4d247f154c7f3')}
# {'BusinessName': 'La Friends Pizzeria',
#  '_id': ObjectId('6584a6198bc4d247f154c7f4')}
# {'BusinessName': 'The Lane', '_id': ObjectId('6584a6198bc4d247f154c7f5')}
# {'BusinessName': 'Deal Beach Parlour',
#  '_id': ObjectId('6584a6198bc4d247f154c7f6')}
# {'BusinessName': 'The Grapevine cafe',
#  '_id': ObjectId('6584a6198bc4d247f154c7f7')}
# {'BusinessName': 'Louis Armstrong', '_id': ObjectId('6584a6198bc4d247f154c7f8')}
# {'BusinessName': 'Wellingtons', '_id': ObjectId('6584a6198bc4d247f154c7f9')}
# {'BusinessName': 'Iceland', '_id': ObjectId('6584a6198bc4d247f154c7fa')}
# {'BusinessName': 'Premier Mini Mart',
#  '_id': ObjectId('6584a6198bc4d247f154c7fb')}
# {'BusinessName': 'Luscious Chinese Takeaway',
#  '_id': ObjectId('6584a6198bc4d247f154c7fc')}
# {'BusinessName': 'Sea View', '_id': ObjectId('6584a6198bc4d247f154c7fd')}
# {'BusinessName': 'The Meatball Company',
#  '_id': ObjectId('6584a6198bc4d247f154c7fe')}
# {'BusinessName': 'Dine India, The Clarendon Hotel',
#  '_id': ObjectId('6584a6198bc4d247f154c7ff')}
# {'BusinessName': 'Aspendos', '_id': ObjectId('6584a6198bc4d247f154c800')}
# {'BusinessName': 'The Bohemian', '_id': ObjectId('6584a6198bc4d247f154c801')}
# {'BusinessName': 'The Thirsty Scarecrow',
#  '_id': ObjectId('6584a6198bc4d247f154c802')}
# {'BusinessName': 'Pizza Gogo', '_id': ObjectId('6584a6198bc4d247f154c803')}
# {'BusinessName': 'Salentinos', '_id': ObjectId('6584a6198bc4d247f154c804')}
# {'BusinessName': 'Roosters Inn', '_id': ObjectId('6584a6198bc4d247f154c805')}
# {'BusinessName': 'Cabin Bar, The Clarendon Hotel',
#  '_id': ObjectId('6584a6198bc4d247f154c806')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('6584a6198bc4d247f154c807')}
# {'BusinessName': 'Deal Direct Fish & Shellfish',
#  '_id': ObjectId('6584a6198bc4d247f154c808')}
# {'BusinessName': 'Starburger Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c809')}
# {'BusinessName': 'Waterfront Hotel',
#  '_id': ObjectId('6584a6198bc4d247f154c80a')}
# {'BusinessName': 'Dolphin Kebab', '_id': ObjectId('6584a6198bc4d247f154c80b')}
# {'BusinessName': 'The Gaiety Bar', '_id': ObjectId('6584a6198bc4d247f154c80c')}
# {'BusinessName': 'Kings Coffee Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c80d')}
# {'BusinessName': 'Bartlett and White',
#  '_id': ObjectId('6584a6198bc4d247f154c80e')}
# {'BusinessName': 'J J Wood', '_id': ObjectId('6584a6198bc4d247f154c80f')}
# {'BusinessName': 'Poundstretcher', '_id': ObjectId('6584a6198bc4d247f154c810')}
# {'BusinessName': 'Farmfoods', '_id': ObjectId('6584a6198bc4d247f154c811')}
# {'BusinessName': 'Poundstretcher', '_id': ObjectId('6584a6198bc4d247f154c812')}
# {'BusinessName': 'Asda', '_id': ObjectId('6584a6198bc4d247f154c813')}
# {'BusinessName': 'Clare House', '_id': ObjectId('6584a6198bc4d247f154c814')}
# {'BusinessName': 'Strand Coffee House',
#  '_id': ObjectId('6584a6198bc4d247f154c815')}
# {'BusinessName': 'Peckish', '_id': ObjectId('6584a6198bc4d247f154c816')}
# {'BusinessName': 'The Just Reproach',
#  '_id': ObjectId('6584a6198bc4d247f154c817')}
# {'BusinessName': 'Route One', '_id': ObjectId('6584a6198bc4d247f154c818')}
# {'BusinessName': 'Love Drinks', '_id': ObjectId('6584a6198bc4d247f154c819')}
# {'BusinessName': 'Holland & Barrett',
#  '_id': ObjectId('6584a6198bc4d247f154c81a')}
# {'BusinessName': 'Royal Snooker Club',
#  '_id': ObjectId('6584a6198bc4d247f154c81b')}
# {'BusinessName': "Al's Bakery", '_id': ObjectId('6584a6198bc4d247f154c81c')}
# {'BusinessName': 'The Goodwin', '_id': ObjectId('6584a6198bc4d247f154c81d')}
# {'BusinessName': 'Star of India', '_id': ObjectId('6584a6198bc4d247f154c81e')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('6584a6198bc4d247f154c81f')}
# {'BusinessName': 'Westbury House', '_id': ObjectId('6584a6198bc4d247f154c820')}
# {'BusinessName': "Domino's Pizza", '_id': ObjectId('6584a6198bc4d247f154c821')}
# {'BusinessName': "The Meat'in Place",
#  '_id': ObjectId('6584a6198bc4d247f154c822')}
# {'BusinessName': 'Iceland', '_id': ObjectId('6584a6198bc4d247f154c823')}
# {'BusinessName': 'M & Co', '_id': ObjectId('6584a6198bc4d247f154c824')}
# {'BusinessName': 'BonneBombe', '_id': ObjectId('6584a6198bc4d247f154c825')}
# {'BusinessName': 'Sir Norman Wisdom',
#  '_id': ObjectId('6584a6198bc4d247f154c826')}
# {'BusinessName': 'The Lane Bakery', '_id': ObjectId('6584a6198bc4d247f154c827')}
# {'BusinessName': 'Royal Hotel', '_id': ObjectId('6584a6198bc4d247f154c828')}
# {'BusinessName': 'Margheritas', '_id': ObjectId('6584a6198bc4d247f154c829')}
# {'BusinessName': '81 Beach Street', '_id': ObjectId('6584a6198bc4d247f154c82a')}
# {'BusinessName': 'Starbucks', '_id': ObjectId('6584a6198bc4d247f154c82b')}
# {'BusinessName': 'Royal British Legion Downs Club',
#  '_id': ObjectId('6584a6198bc4d247f154c82c')}
# {'BusinessName': 'Poundland', '_id': ObjectId('6584a6198bc4d247f154c82d')}
# {'BusinessName': 'Milaad Tandoori Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c82e')}
# {'BusinessName': 'Tower Burgers and Shakes',
#  '_id': ObjectId('6584a6198bc4d247f154c82f')}
# {'BusinessName': 'Smugglers Records',
#  '_id': ObjectId('6584a6198bc4d247f154c830')}
# {'BusinessName': 'Vanes', '_id': ObjectId('6584a6198bc4d247f154c831')}
# {'BusinessName': 'Tower Kebab', '_id': ObjectId('6584a6198bc4d247f154c832')}
# {'BusinessName': "Kerry's Bakehouse & Eatery",
#  '_id': ObjectId('6584a6198bc4d247f154c833')}
# {'BusinessName': 'Alexander House Care Home',
#  '_id': ObjectId('6584a6198bc4d247f154c834')}
# {'BusinessName': 'The Dining Club', '_id': ObjectId('6584a6198bc4d247f154c835')}
# {'BusinessName': 'Mild White', '_id': ObjectId('6584a6198bc4d247f154c836')}
# {'BusinessName': 'The Eagle', '_id': ObjectId('6584a6198bc4d247f154c837')}
# {'BusinessName': 'McCarthy & Stone - Dover',
#  '_id': ObjectId('6584a6198bc4d247f154c838')}
# {'BusinessName': 'Tides Leisure Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c839')}
# {'BusinessName': 'Queen Street Tap',
#  '_id': ObjectId('6584a6198bc4d247f154c83a')}
# {'BusinessName': 'The Original Factory Shop',
#  '_id': ObjectId('6584a6198bc4d247f154c83b')}
# {'BusinessName': 'The Seagull', '_id': ObjectId('6584a6198bc4d247f154c83c')}
# {'BusinessName': 'Ocean Rooms', '_id': ObjectId('6584a6198bc4d247f154c83d')}
# {'BusinessName': 'Longfield Local', '_id': ObjectId('6584a6198bc4d247f154c83e')}
# {'BusinessName': 'J C Rook & Sons Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c83f')}
# {'BusinessName': 'Sandown', '_id': ObjectId('6584a6198bc4d247f154c840')}
# {'BusinessName': 'Admiral Harvey', '_id': ObjectId('6584a6198bc4d247f154c841')}
# {'BusinessName': 'Happy Fryer', '_id': ObjectId('6584a6198bc4d247f154c842')}
# {'BusinessName': 'Hope & Lane', '_id': ObjectId('6584a6198bc4d247f154c843')}
# {'BusinessName': 'Victuals & Co', '_id': ObjectId('6584a6198bc4d247f154c844')}
# {'BusinessName': 'Deal Centre For The Retired',
#  '_id': ObjectId('6584a6198bc4d247f154c845')}
# {'BusinessName': 'The Black Pig', '_id': ObjectId('6584a6198bc4d247f154c846')}
# {'BusinessName': 'Frog and Scot', '_id': ObjectId('6584a6198bc4d247f154c847')}
# {'BusinessName': 'The Canterbury fruit stalls',
#  '_id': ObjectId('6584a6198bc4d247f154c848')}
# {'BusinessName': 'Filberts Foods', '_id': ObjectId('6584a6198bc4d247f154c849')}
# {'BusinessName': 'Astor Theatre', '_id': ObjectId('6584a6198bc4d247f154c84a')}
# {'BusinessName': 'Soul Chef Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c84b')}
# {'BusinessName': 'Bridge Street News',
#  '_id': ObjectId('6584a6198bc4d247f154c84c')}
# {'BusinessName': 'Middle Street Fish Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c84d')}
# {'BusinessName': 'The Rose Hotel', '_id': ObjectId('6584a6198bc4d247f154c84e')}
# {'BusinessName': 'Longfield Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c84f')}
# {'BusinessName': 'Aldi Stores Ltd', '_id': ObjectId('6584a6198bc4d247f154c850')}
# {'BusinessName': 'The Three Compasses',
#  '_id': ObjectId('6584a6198bc4d247f154c851')}
# {'BusinessName': 'Le Pinardier', '_id': ObjectId('6584a6198bc4d247f154c852')}
# {'BusinessName': 'No Name Shop', '_id': ObjectId('6584a6198bc4d247f154c853')}
# {'BusinessName': 'Your Shop', '_id': ObjectId('6584a6198bc4d247f154c854')}
# {'BusinessName': 'Tea Cafe Restaurant',
#  '_id': ObjectId('6584a6198bc4d247f154c855')}
# {'BusinessName': 'Dover Grammar School For Girls',
#  '_id': ObjectId('6584a6198bc4d247f154c856')}
# {'BusinessName': 'S.Mart Offlicense & Convenience',
#  '_id': ObjectId('6584a6198bc4d247f154c857')}
# {'BusinessName': 'West Street Mini Market',
#  '_id': ObjectId('6584a6198bc4d247f154c858')}
# {'BusinessName': 'Arno & Co', '_id': ObjectId('6584a6198bc4d247f154c859')}
# {'BusinessName': 'The History Project',
#  '_id': ObjectId('6584a6198bc4d247f154c85a')}
# {'BusinessName': 'The Merchant of Relish',
#  '_id': ObjectId('6584a6198bc4d247f154c85b')}
# {'BusinessName': 'Eagle Tavern', '_id': ObjectId('6584a6198bc4d247f154c85c')}
# {'BusinessName': 'Peppers Healthfoods',
#  '_id': ObjectId('6584a6198bc4d247f154c85d')}
# {'BusinessName': 'Miretti Pasticceria',
#  '_id': ObjectId('6584a6198bc4d247f154c85e')}
# {'BusinessName': 'Jenkins & Son', '_id': ObjectId('6584a6198bc4d247f154c85f')}
# {'BusinessName': 'Creative Minds Nursery',
#  '_id': ObjectId('6584a6198bc4d247f154c860')}
# {'BusinessName': 'Dial-A-Pizza', '_id': ObjectId('6584a6198bc4d247f154c861')}
# {'BusinessName': 'Spires Hospitality Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c862')}
# {'BusinessName': 'Deal Town Rangers Football Club',
#  '_id': ObjectId('6584a6198bc4d247f154c863')}
# {'BusinessName': 'Treetops Pre School',
#  '_id': ObjectId('6584a6198bc4d247f154c864')}
# {'BusinessName': 'Kent Museum of the Moving Image',
#  '_id': ObjectId('6584a6198bc4d247f154c865')}
# {'BusinessName': 'Felbrigg House Residential Home',
#  '_id': ObjectId('6584a6198bc4d247f154c866')}
# {'BusinessName': 'Goodwin Academy', '_id': ObjectId('6584a6198bc4d247f154c867')}
# {'BusinessName': 'Jerk n Tingz', '_id': ObjectId('6584a6198bc4d247f154c868')}
# {'BusinessName': 'Kaleidascope Childcare Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c869')}
# {'BusinessName': 'Deal Grill', '_id': ObjectId('6584a6198bc4d247f154c86a')}
# {'BusinessName': 'Westbank Guest House',
#  '_id': ObjectId('6584a6198bc4d247f154c86b')}
# {'BusinessName': "Sainsbury's", '_id': ObjectId('6584a6198bc4d247f154c86c')}
# {'BusinessName': 'Spires Bistro, The Landmark Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c86d')}
# {'BusinessName': 'The Daily Grind', '_id': ObjectId('6584a6198bc4d247f154c86e')}
# {'BusinessName': 'River Caterers', '_id': ObjectId('6584a6198bc4d247f154c86f')}
# {'BusinessName': 'Tower Hamlets Stores',
#  '_id': ObjectId('6584a6198bc4d247f154c870')}
# {'BusinessName': "Welly's Coffee House & Bar",
#  '_id': ObjectId('6584a6198bc4d247f154c871')}
# {'BusinessName': "Sid's ice cream and donut parlour",
#  '_id': ObjectId('6584a6198bc4d247f154c872')}
# {'BusinessName': 'Sweetzuk', '_id': ObjectId('6584a6198bc4d247f154c873')}
# {'BusinessName': 'Direct Pizza Company',
#  '_id': ObjectId('6584a6198bc4d247f154c874')}
# {'BusinessName': "Bloody Mary's", '_id': ObjectId('6584a6198bc4d247f154c875')}
# {'BusinessName': "Welly's Coffeehouse and Bar",
#  '_id': ObjectId('6584a6198bc4d247f154c876')}
# {'BusinessName': 'M Smith Butchers',
#  '_id': ObjectId('6584a6198bc4d247f154c877')}
# {'BusinessName': 'The Bar', '_id': ObjectId('6584a6198bc4d247f154c878')}
# {'BusinessName': 'Mileage', '_id': ObjectId('6584a6198bc4d247f154c879')}
# {'BusinessName': 'Dewdrop Inn', '_id': ObjectId('6584a6198bc4d247f154c87a')}
# {'BusinessName': 'Deal Bowling Club',
#  '_id': ObjectId('6584a6198bc4d247f154c87b')}
# {'BusinessName': 'The Salvation Army',
#  '_id': ObjectId('6584a6198bc4d247f154c87c')}
# {'BusinessName': "Brenda's Kitchen",
#  '_id': ObjectId('6584a6198bc4d247f154c87d')}
# {'BusinessName': "Bear's Well", '_id': ObjectId('6584a6198bc4d247f154c87e')}
# {'BusinessName': 'Ship Inn', '_id': ObjectId('6584a6198bc4d247f154c87f')}
# {'BusinessName': 'Trinity Church', '_id': ObjectId('6584a6198bc4d247f154c880')}
# {'BusinessName': 'Park Convenience Store',
#  '_id': ObjectId('6584a6198bc4d247f154c881')}
# {'BusinessName': 'Top Wok', '_id': ObjectId('6584a6198bc4d247f154c882')}
# {'BusinessName': 'St Edmunds Catholic School Kitchen',
#  '_id': ObjectId('6584a6198bc4d247f154c883')}
# {'BusinessName': 'Co-op', '_id': ObjectId('6584a6198bc4d247f154c884')}
# {'BusinessName': 'Flints', '_id': ObjectId('6584a6198bc4d247f154c885')}
# {'BusinessName': 'Charlton Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c886')}
# {'BusinessName': 'Deal Welfare Club',
#  '_id': ObjectId('6584a6198bc4d247f154c887')}
# {'BusinessName': 'Spindrift Cafe', '_id': ObjectId('6584a6198bc4d247f154c888')}
# {'BusinessName': 'Vale View County Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c889')}
# {'BusinessName': 'Priory Fields School',
#  '_id': ObjectId('6584a6198bc4d247f154c88a')}
# {'BusinessName': 'Priory Fields School Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c88b')}
# {'BusinessName': 'The Alma', '_id': ObjectId('6584a6198bc4d247f154c88c')}
# {'BusinessName': 'Total Fitness Mix Ltd',
#  '_id': ObjectId('6584a6198bc4d247f154c88d')}
# {'BusinessName': 'Prince Albert', '_id': ObjectId('6584a6198bc4d247f154c88e')}
# {'BusinessName': 'Deal Hoy', '_id': ObjectId('6584a6198bc4d247f154c88f')}
# {'BusinessName': 'Peking Palace', '_id': ObjectId('6584a6198bc4d247f154c890')}
# {'BusinessName': 'Golden Fillet', '_id': ObjectId('6584a6198bc4d247f154c891')}
# {'BusinessName': 'Mill Shop', '_id': ObjectId('6584a6198bc4d247f154c892')}
# {'BusinessName': 'The Mill Inn', '_id': ObjectId('6584a6198bc4d247f154c893')}
# {'BusinessName': 'Co-op', '_id': ObjectId('6584a6198bc4d247f154c894')}
# {'BusinessName': 'MFG Deal Service Station',
#  '_id': ObjectId('6584a6198bc4d247f154c895')}
# {'BusinessName': 'Brook Lodge', '_id': ObjectId('6584a6198bc4d247f154c896')}
# {'BusinessName': 'BP/Budgens Deal', '_id': ObjectId('6584a6198bc4d247f154c897')}
# {'BusinessName': 'Deal Angling Club 1919',
#  '_id': ObjectId('6584a6198bc4d247f154c898')}
# {'BusinessName': 'Magic Chef', '_id': ObjectId('6584a6198bc4d247f154c899')}
# {'BusinessName': 'The Boba Dragon', '_id': ObjectId('6584a6198bc4d247f154c89a')}
# {'BusinessName': 'Greggs', '_id': ObjectId('6584a6198bc4d247f154c89b')}
# {'BusinessName': 'Spar', '_id': ObjectId('6584a6198bc4d247f154c89c')}
# {'BusinessName': 'Good Choice', '_id': ObjectId('6584a6198bc4d247f154c89d')}
# {'BusinessName': 'Pizza Plus', '_id': ObjectId('6584a6198bc4d247f154c89e')}
# {'BusinessName': 'Pizza Sprint', '_id': ObjectId('6584a6198bc4d247f154c89f')}
# {'BusinessName': "Tony's Fish Bar", '_id': ObjectId('6584a6198bc4d247f154c8a0')}
# {'BusinessName': 'London Kebab House',
#  '_id': ObjectId('6584a6198bc4d247f154c8a1')}
# {'BusinessName': 'Kent Bakery Co', '_id': ObjectId('6584a6198bc4d247f154c8a2')}
# {'BusinessName': 'White Cliffs Tandoori',
#  '_id': ObjectId('6584a6198bc4d247f154c8a3')}
# {'BusinessName': 'Star Pizza', '_id': ObjectId('6584a6198bc4d247f154c8a4')}
# {'BusinessName': 'Kong Sing', '_id': ObjectId('6584a6198bc4d247f154c8a5')}
# {'BusinessName': 'Little India', '_id': ObjectId('6584a6198bc4d247f154c8a6')}
# {'BusinessName': 'Win Win Chinese Takeaway',
#  '_id': ObjectId('6584a6198bc4d247f154c8a7')}
# {'BusinessName': 'Friendship Lunch',
#  '_id': ObjectId('6584a6198bc4d247f154c8a8')}
# {'BusinessName': 'Saracens Head', '_id': ObjectId('6584a6198bc4d247f154c8a9')}
# {'BusinessName': 'Brunch Box', '_id': ObjectId('6584a6198bc4d247f154c8aa')}
# {'BusinessName': 'Ocean Fish and Chips',
#  '_id': ObjectId('6584a6198bc4d247f154c8ab')}
# {'BusinessName': 'Deal Walmer & Kingsdown Rowing Club',
#  '_id': ObjectId('6584a6198bc4d247f154c8ac')}
# {'BusinessName': 'Afyon', '_id': ObjectId('6584a6198bc4d247f154c8ad')}
# {'BusinessName': 'Co-op', '_id': ObjectId('6584a6198bc4d247f154c8ae')}
# {'BusinessName': 'Newsmarket', '_id': ObjectId('6584a6198bc4d247f154c8af')}
# {'BusinessName': 'Boars Head', '_id': ObjectId('6584a6198bc4d247f154c8b0')}
# {'BusinessName': 'Crown and Sceptre',
#  '_id': ObjectId('6584a6198bc4d247f154c8b1')}
# {'BusinessName': 'Next Steps Pre-school',
#  '_id': ObjectId('6584a6198bc4d247f154c8b2')}
# {'BusinessName': 'Foresters Inn', '_id': ObjectId('6584a6198bc4d247f154c8b3')}
# {'BusinessName': 'Barton Junior School Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c8b4')}
# {'BusinessName': 'St Richards Church Hall Centre',
#  '_id': ObjectId('6584a6198bc4d247f154c8b5')}
# {'BusinessName': 'Barton County Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c8b6')}
# {'BusinessName': 'Oasis Chinese Take-Away',
#  '_id': ObjectId('6584a6198bc4d247f154c8b7')}
# {'BusinessName': 'Tesco', '_id': ObjectId('6584a6198bc4d247f154c8b8')}
# {'BusinessName': 'Chance Inn', '_id': ObjectId('6584a6198bc4d247f154c8b9')}
# {'BusinessName': "Trudella's", '_id': ObjectId('6584a6198bc4d247f154c8ba')}
# {'BusinessName': "Dover Working Man's Club & Institute",
#  '_id': ObjectId('6584a6198bc4d247f154c8bb')}
# {'BusinessName': 'Mace', '_id': ObjectId('6584a6198bc4d247f154c8bc')}
# {'BusinessName': 'Fryer Tuck', '_id': ObjectId('6584a6198bc4d247f154c8bd')}
# {'BusinessName': 'Nirja Convenience Store',
#  '_id': ObjectId('6584a6198bc4d247f154c8be')}
# {'BusinessName': 'New Century Nursery',
#  '_id': ObjectId('6584a6198bc4d247f154c8bf')}
# {'BusinessName': 'Deal Christian Fellowship Trust',
#  '_id': ObjectId('6584a6198bc4d247f154c8c0')}
# {'BusinessName': 'Old Lantern Inn', '_id': ObjectId('6584a6198bc4d247f154c8c1')}
# {'BusinessName': 'Langdon School Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c8c2')}
# {'BusinessName': 'Whole School Meals',
#  '_id': ObjectId('6584a6198bc4d247f154c8c3')}
# {'BusinessName': 'Li-Hao', '_id': ObjectId('6584a6198bc4d247f154c8c4')}
# {'BusinessName': 'Oriental Express',
#  '_id': ObjectId('6584a6198bc4d247f154c8c5')}
# {'BusinessName': 'Key Stores', '_id': ObjectId('6584a6198bc4d247f154c8c6')}
# {'BusinessName': 'Kent Community Health Foundation',
#  '_id': ObjectId('6584a6198bc4d247f154c8c7')}
# {'BusinessName': 'Clay Pigeon Club',
#  '_id': ObjectId('6584a6198bc4d247f154c8c8')}
# {'BusinessName': 'Ann and Pams Florist',
#  '_id': ObjectId('6584a6198bc4d247f154c8c9')}
# {'BusinessName': 'Deal Town Football Supporters Club',
#  '_id': ObjectId('6584a6198bc4d247f154c8ca')}
# {'BusinessName': 'Rainbow Preschool',
#  '_id': ObjectId('6584a6198bc4d247f154c8cb')}
# {'BusinessName': 'Tennessee Fried Chicken',
#  '_id': ObjectId('6584a6198bc4d247f154c8cc')}
# {'BusinessName': 'Londis Stores', '_id': ObjectId('6584a6198bc4d247f154c8cd')}
# {'BusinessName': 'Londis T/A Right Choice',
#  '_id': ObjectId('6584a6198bc4d247f154c8ce')}
# {'BusinessName': 'Happy Feet Nursery',
#  '_id': ObjectId('6584a6198bc4d247f154c8cf')}
# {'BusinessName': 'Skylight Cafe', '_id': ObjectId('6584a6198bc4d247f154c8d0')}
# {'BusinessName': 'Aldi', '_id': ObjectId('6584a6198bc4d247f154c8d1')}
# {'BusinessName': 'One Church Dover',
#  '_id': ObjectId('6584a6198bc4d247f154c8d2')}
# {'BusinessName': "Engel's Paradise (Bistro)",
#  '_id': ObjectId('6584a6198bc4d247f154c8d3')}
# {'BusinessName': 'Sutherland House',
#  '_id': ObjectId('6584a6198bc4d247f154c8d4')}
# {'BusinessName': 'The Sportsman', '_id': ObjectId('6584a6198bc4d247f154c8d5')}
# {'BusinessName': 'The Smugglers Cafe',
#  '_id': ObjectId('6584a6198bc4d247f154c8d6')}
# {'BusinessName': 'Breakwater Mobile Bar',
#  '_id': ObjectId('6584a6198bc4d247f154c8d7')}
# {'BusinessName': 'Cameron Lodge', '_id': ObjectId('6584a6198bc4d247f154c8d8')}
# {'BusinessName': 'Breakwater Tap House and Pizzeria',
#  '_id': ObjectId('6584a6198bc4d247f154c8d9')}
# {'BusinessName': 'White Cliffs Bakery',
#  '_id': ObjectId('6584a6198bc4d247f154c8da')}
# {'BusinessName': 'St Martins School Breakfast Club',
#  '_id': ObjectId('6584a6198bc4d247f154c8db')}
# {'BusinessName': 'Bowling Green Tavern',
#  '_id': ObjectId('6584a6198bc4d247f154c8dc')}
# {'BusinessName': 'St Martins County Primary School',
#  '_id': ObjectId('6584a6198bc4d247f154c8dd')}
# {'BusinessName': 'Linwood Under Fives Preschool',
#  '_id': ObjectId('6584a6198bc4d247f154c8de')}
# {'BusinessName': 'Sandown School', '_id': ObjectId('6584a6198bc4d247f154c8df')}
# {'BusinessName': 'Tiny Turtles Nursery',
#  '_id': ObjectId('6584a6198bc4d247f154c8e0')}
# {'BusinessName': 'Yummy Takeaway', '_id': ObjectId('6584a6198bc4d247f154c8e1')}
# {'BusinessName': "Daisy's Kitchen", '_id': ObjectId('6584a6198bc4d247f154c8e2')}
# {'BusinessName': 'Magnet House', '_id': ObjectId('6584a6198bc4d247f154c8e3')}
# {'BusinessName': 'Harmonia Village',
#  '_id': ObjectId('6584a6198bc4d247f154c8e4')}
# {'BusinessName': 'Dover Grammar School For Boys',
#  '_id': ObjectId('6584a6198bc4d247f154c8e5')}
# {'BusinessName': 'League Of Friends Of Dover Hospitals',
#  '_id': ObjectId('6584a6198bc4d247f154c8e6')}
# {'BusinessName': 'The Diamond', '_id': ObjectId('6584a6198bc4d247f154c8e7')}
# {'BusinessName': "Kelly's Snacks", '_id': ObjectId('6584a6198bc4d247f154c8e8')}
# {'BusinessName': 'The Farrier Freehouse',
#  '_id': ObjectId('6584a6198bc4d247f154c8e9')}
# {'BusinessName': 'Ripplevale School',
#  '_id': ObjectId('6584a6198bc4d247f154c8ea')}
# {'BusinessName': 'King Edward Store',
#  '_id': ObjectId('6584a6198bc4d247f154c8eb')}
# ...
# {'BusinessName': 'Namaste Sandwich',
#  '_id': ObjectId('6584a61a8bc4d247f154ccfa')}
# {'BusinessName': 'Luigis', '_id': ObjectId('6584a61a8bc4d247f154ccfb')}
# {'BusinessName': 'Sids ice cream and donut parlour',
#  '_id': ObjectId('6584a61a8bc4d247f154ccfc')}
# {'BusinessName': 'Di Vino', '_id': ObjectId('6584a61a8bc4d247f154ccfd')}
# {'BusinessName': 'The Deep Blue', '_id': ObjectId('6584a61a8bc4d247f154ccfe')}
# {'BusinessName': 'St Barts Day Nurseries Out Of School Centre',
#  '_id': ObjectId('6584a61a8bc4d247f154cd01')}
# {'BusinessName': 'Sandwich County Junior School',
#  '_id': ObjectId('6584a61a8bc4d247f154cd02')}
# {'BusinessName': 'Bell Hotel', '_id': ObjectId('6584a61a8bc4d247f154cd06')}
# {'BusinessName': 'The Admiral Owen',
#  '_id': ObjectId('6584a61a8bc4d247f154cd0e')}
# {'BusinessName': 'Sandwich Wildlife Park Cafe',
#  '_id': ObjectId('6584a61a8bc4d247f154cd14')}
# {'BusinessName': 'Sandwich Wildlife Park',
#  '_id': ObjectId('6584a61a8bc4d247f154cd16')}
# {'BusinessName': 'Crispin Inn', '_id': ObjectId('6584a61a8bc4d247f154cd19')}
# {'BusinessName': 'My Happy Place Cafe',
#  '_id': ObjectId('6584a61a8bc4d247f154cd1a')}
# {'BusinessName': 'The Haven', '_id': ObjectId('6584a61a8bc4d247f154cd1c')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('6584a61a8bc4d247f154cd1d')}
# {'BusinessName': 'Sandwich Convenience Store',
#  '_id': ObjectId('6584a61a8bc4d247f154cd1f')}
# {'BusinessName': 'Al Taco', '_id': ObjectId('6584a61a8bc4d247f154cd21')}
# {'BusinessName': 'The Toll Bridge', '_id': ObjectId('6584a61a8bc4d247f154cd22')}
# {'BusinessName': 'Sandwich Kebab  Pizza',
#  '_id': ObjectId('6584a61a8bc4d247f154cd23')}
# {'BusinessName': 'Tan-Bueno', '_id': ObjectId('6584a61a8bc4d247f154cd24')}
# {'BusinessName': 'Five Bells', '_id': ObjectId('6584a61a8bc4d247f154cd2a')}
# {'BusinessName': 'Goats That Dance',
#  '_id': ObjectId('6584a61a8bc4d247f154cd2b')}
# {'BusinessName': 'Friendship Lunch Club',
#  '_id': ObjectId('6584a61a8bc4d247f154cd2c')}
# {'BusinessName': 'The Sandwich Bakery Company',
#  '_id': ObjectId('6584a61a8bc4d247f154cd30')}
# {'BusinessName': 'St Peters B&B', '_id': ObjectId('6584a61a8bc4d247f154cd32')}
# {'BusinessName': 'No Name Shop and Bistro',
#  '_id': ObjectId('6584a61a8bc4d247f154cd33')}
# {'BusinessName': 'Age Concern Sandwich',
#  '_id': ObjectId('6584a61a8bc4d247f154cd34')}
# {'BusinessName': 'The Sandwich Shop',
#  '_id': ObjectId('6584a61a8bc4d247f154cd35')}
# {'BusinessName': 'The Waiting Room',
#  '_id': ObjectId('6584a61a8bc4d247f154cd36')}
# {'BusinessName': 'Brambles Bed and Breakfast',
#  '_id': ObjectId('6584a61a8bc4d247f154cd38')}
# {'BusinessName': 'Eastry Fish Bar', '_id': ObjectId('6584a61a8bc4d247f154cd39')}
# {'BusinessName': 'Spar', '_id': ObjectId('6584a61a8bc4d247f154cd3b')}
# {'BusinessName': 'My Thai Ltd', '_id': ObjectId('6584a61a8bc4d247f154cd3d')}
# {'BusinessName': 'Bella Amalfi', '_id': ObjectId('6584a61a8bc4d247f154cd3e')}
# {'BusinessName': 'Ossies Fish & Chips',
#  '_id': ObjectId('6584a61a8bc4d247f154cd44')}
# {'BusinessName': 'Fleur De Lis', '_id': ObjectId('6584a61a8bc4d247f154cd45')}
# {'BusinessName': 'The Market Inn', '_id': ObjectId('6584a61a8bc4d247f154cd46')}
# {'BusinessName': 'Smugglers Beer and Music Cafe',
#  '_id': ObjectId('6584a61a8bc4d247f154cd49')}
# {'BusinessName': 'Woodpecker Court Youth Activities',
#  '_id': ObjectId('6584a61a8bc4d247f154cd4b')}
# {'BusinessName': 'Visitor Information Centre',
#  '_id': ObjectId('6584a61a8bc4d247f154cd4d')}
# {'BusinessName': 'The Strand Street Kitchen',
#  '_id': ObjectId('6584a61a8bc4d247f154cd4f')}
# {'BusinessName': 'Tilmanstone Colliery Sports Club',
#  '_id': ObjectId('6584a61a8bc4d247f154cd50')}
# {'BusinessName': 'Tots R Us Preschool',
#  '_id': ObjectId('6584a61a8bc4d247f154cd51')}
# {'BusinessName': 'Eythorne Elvington Breakfast Club',
#  '_id': ObjectId('6584a61a8bc4d247f154cd52')}
# {'BusinessName': "The Sunflower Children's Centre",
#  '_id': ObjectId('6584a61a8bc4d247f154cd53')}
# {'BusinessName': 'Nourish Contract Catering Group@',
#  '_id': ObjectId('6584a61a8bc4d247f154cd55')}
# {'BusinessName': 'Mermaids Locker', '_id': ObjectId('6584a61a8bc4d247f154cd56')}
# {'BusinessName': 'The Sandwich Sausage Company',
#  '_id': ObjectId('6584a61a8bc4d247f154cd57')}
# {'BusinessName': 'Amigos', '_id': ObjectId('6584a61a8bc4d247f154cd58')}
# {'BusinessName': 'The Smokehouse', '_id': ObjectId('6584a61a8bc4d247f154cd5a')}
# {'BusinessName': 'India Village Tandoori',
#  '_id': ObjectId('6584a61a8bc4d247f154cd5b')}
# {'BusinessName': 'Chutney Masala', '_id': ObjectId('6584a61a8bc4d247f154cd60')}
# {'BusinessName': 'Hays Shack', '_id': ObjectId('6584a61a8bc4d247f154cd63')}
# {'BusinessName': 'The New Inn', '_id': ObjectId('6584a61a8bc4d247f154cd64')}
# {'BusinessName': 'Merry Go Round Pre School',
#  '_id': ObjectId('6584a61a8bc4d247f154cd66')}
# {'BusinessName': 'First Choice', '_id': ObjectId('6584a61a8bc4d247f154cd67')}
# {'BusinessName': 'Optima Care Ltd', '_id': ObjectId('6584a61a8bc4d247f154cd69')}
# {'BusinessName': 'S and C Baitup Family Butcher',
#  '_id': ObjectId('6584a61a8bc4d247f154cd6a')}
# {'BusinessName': 'Eastry Village Supermarket',
#  '_id': ObjectId('6584a61a8bc4d247f154cd6b')}
# {'BusinessName': 'Bakers Dozen', '_id': ObjectId('6584a61a8bc4d247f154cd6c')}
# {'BusinessName': 'Red Cow Inn', '_id': ObjectId('6584a61a8bc4d247f154cd6d')}
# {'BusinessName': 'Co-op', '_id': ObjectId('6584a61a8bc4d247f154cd7b')}
# {'BusinessName': 'The Empire Cinema',
#  '_id': ObjectId('6584a61a8bc4d247f154cd7e')}
# {'BusinessName': 'Bickers', '_id': ObjectId('6584a61a8bc4d247f154cd82')}
# {'BusinessName': 'Java Restaurant', '_id': ObjectId('6584a61a8bc4d247f154cd85')}
# {'BusinessName': 'Java 2 Go', '_id': ObjectId('6584a61a8bc4d247f154cd88')}
# {'BusinessName': 'Bubbles Nursery And Out Of School Club',
#  '_id': ObjectId('6584a61a8bc4d247f154cd9b')}
# {'BusinessName': 'Kings Arms Hotel',
#  '_id': ObjectId('6584a61a8bc4d247f154cd9f')}
# {'BusinessName': 'ECF', '_id': ObjectId('6584a61a8bc4d247f154cda6')}
# {'BusinessName': 'Sandwich Infant School',
#  '_id': ObjectId('6584a61a8bc4d247f154cda8')}
# {'BusinessName': 'Eastry Church Of England Primary School',
#  '_id': ObjectId('6584a61a8bc4d247f154cdad')}
# {'BusinessName': 'The Creative Kitchen',
#  '_id': ObjectId('6584a61a8bc4d247f154cdb9')}
# {'BusinessName': 'Elvington Village Stores',
#  '_id': ObjectId('6584a61a8bc4d247f154cdc5')}
# {'BusinessName': 'Golden Kitchen', '_id': ObjectId('6584a61a8bc4d247f154cdc7')}
# {'BusinessName': 'Elvington Masala',
#  '_id': ObjectId('6584a61a8bc4d247f154cdcb')}
# {'BusinessName': 'Bell Inn', '_id': ObjectId('6584a61a8bc4d247f154cddb')}
# {'BusinessName': 'Elvington & Eythorne Heritage Group',
#  '_id': ObjectId('6584a61a8bc4d247f154cde8')}
# {'BusinessName': 'Nourish Contract Catering Group@',
#  '_id': ObjectId('6584a61a8bc4d247f154cdef')}
# {'BusinessName': 'Sibertswold School Breakfast Club',
#  '_id': ObjectId('6584a61a8bc4d247f154cdf0')}
# {'BusinessName': 'Travelodge Sandwich',
#  '_id': ObjectId('6584a61a8bc4d247f154ce0f')}
# {'BusinessName': 'LEON', '_id': ObjectId('6584a61a8bc4d247f154ce1a')}
# {'BusinessName': 'The Field Kitchen',
#  '_id': ObjectId('6584a61a8bc4d247f154ce26')}
# {'BusinessName': 'White Mill Farm Shop',
#  '_id': ObjectId('6584a61a8bc4d247f154ce27')}
# {'BusinessName': 'T42 Community Cafe',
#  '_id': ObjectId('6584a61a8bc4d247f154ce3b')}
# {'BusinessName': 'Brambling House', '_id': ObjectId('6584a61a8bc4d247f154ce3d')}
# {'BusinessName': 'Brambling Lodge Residential Home',
#  '_id': ObjectId('6584a61a8bc4d247f154ce3f')}
# {'BusinessName': 'The Oast B&B', '_id': ObjectId('6584a61a8bc4d247f154ce40')}
# {'BusinessName': 'Co-op', '_id': ObjectId('6584a61a8bc4d247f154ce43')}
# {'BusinessName': 'Colonels Cafe', '_id': ObjectId('6584a61a8bc4d247f154ce46')}
# {'BusinessName': 'Pegwell Bay Nursery',
#  '_id': ObjectId('6584a61a8bc4d247f154ce6a')}
# {'BusinessName': 'Able Catering', '_id': ObjectId('6584a61a8bc4d247f154ce6c')}
# {'BusinessName': 'Baypoint Sandwich',
#  '_id': ObjectId('6584a61a8bc4d247f154ce72')}
# {'BusinessName': 'Premier Stores', '_id': ObjectId('6584a61a8bc4d247f154ce81')}
# {'BusinessName': 'Subway', '_id': ObjectId('6584a61a8bc4d247f154ce83')}
# {'BusinessName': 'Richborough Service Station',
#  '_id': ObjectId('6584a61a8bc4d247f154ce87')}
# {'BusinessName': 'Kfc', '_id': ObjectId('6584a61a8bc4d247f154ce8c')}
# {'BusinessName': 'Knowlton Court', '_id': ObjectId('6584a61a8bc4d247f154ceb4')}
# {'BusinessName': 'C&S Catering (2)',
#  '_id': ObjectId('6584a61a8bc4d247f154ced6')}
# {'BusinessName': 'C&S Catering (1)',
#  '_id': ObjectId('6584a61a8bc4d247f154cee0')}
# {'BusinessName': 'Goss Hall', '_id': ObjectId('6584a61a8bc4d247f154cf47')}
# {'BusinessName': 'King Edward House',
#  '_id': ObjectId('6584a61a8bc4d247f154cf54')}
# {'BusinessName': 'Griffins Head', '_id': ObjectId('6584a61a8bc4d247f154cf59')}
# {'BusinessName': 'The Royal Oak', '_id': ObjectId('6584a61a8bc4d247f154cf6a')}
# {'BusinessName': 'Black Pig', '_id': ObjectId('6584a61a8bc4d247f154cfb7')}
# {'BusinessName': 'Nonington Church Of England Primary School',
#  '_id': ObjectId('6584a61a8bc4d247f154cfcd')}
# {'BusinessName': 'Ash Village Hall',
#  '_id': ObjectId('6584a61a8bc4d247f154cfdb')}
# {'BusinessName': 'Nonington Farms Ltd',
#  '_id': ObjectId('6584a61a8bc4d247f154cfe1')}
# {'BusinessName': 'Welcome', '_id': ObjectId('6584a61a8bc4d247f154cfea')}
# {'BusinessName': 'Staple Pre School',
#  '_id': ObjectId('6584a61a8bc4d247f154cfee')}
# {'BusinessName': "Juliet's Farm Shop and Cafe",
#  '_id': ObjectId('6584a61a8bc4d247f154cfff')}
# {'BusinessName': 'Number 37', '_id': ObjectId('6584a61a8bc4d247f154d004')}
# {'BusinessName': 'The Chequer Inn', '_id': ObjectId('6584a61a8bc4d247f154d011')}
# {'BusinessName': 'Ash Pizza King', '_id': ObjectId('6584a61a8bc4d247f154d019')}
# {'BusinessName': 'St Faiths At Ash School',
#  '_id': ObjectId('6584a61a8bc4d247f154d022')}
# {'BusinessName': 'Poparound', '_id': ObjectId('6584a61a8bc4d247f154d023')}
# {'BusinessName': 'The Volunteer PH',
#  '_id': ObjectId('6584a61a8bc4d247f154d031')}
# {'BusinessName': 'Cartwright & Kelsey Breakfast Club',
#  '_id': ObjectId('6584a61a8bc4d247f154d051')}
# {'BusinessName': 'Fledglings Nursery',
#  '_id': ObjectId('6584a61a8bc4d247f154d054')}
# {'BusinessName': 'Cartwright And Kelsey Primary School',
#  '_id': ObjectId('6584a61a8bc4d247f154d057')}
# {'BusinessName': 'Jackdaw Inn', '_id': ObjectId('6584a61a8bc4d247f154d065')}
# {'BusinessName': 'Goldstone Butchers',
#  '_id': ObjectId('6584a61a8bc4d247f154d07d')}
# {'BusinessName': 'The Curing Shed', '_id': ObjectId('6584a61a8bc4d247f154d081')}
# {'BusinessName': 'B And B Accommodation',
#  '_id': ObjectId('6584a61a8bc4d247f154d086')}
# {'BusinessName': 'Fitzwalter Arms', '_id': ObjectId('6584a61a8bc4d247f154d0ee')}
# {'BusinessName': 'Bennett & Friends Catering + Events',
#  '_id': ObjectId('6584a61a8bc4d247f154d0f7')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('6584a61a8bc4d247f154d0f8')}
# {'BusinessName': 'Bechange', '_id': ObjectId('6584a61a8bc4d247f154d0f9')}
# {'BusinessName': 'The Old Dairy', '_id': ObjectId('6584a61a8bc4d247f154d0fe')}
# {'BusinessName': 'Goodnestone Park',
#  '_id': ObjectId('6584a61a8bc4d247f154d0ff')}
# {'BusinessName': 'Cooked with Love',
#  '_id': ObjectId('6584a61a8bc4d247f154d100')}
# {'BusinessName': 'St Josephs Roman Catholic Primary School',
#  '_id': ObjectId('6584a61a8bc4d247f154d102')}
# {'BusinessName': 'Aylesham And Snowdowns Bowls Club',
#  '_id': ObjectId('6584a61a8bc4d247f154d103')}
# {'BusinessName': 'Kaleidoscope Nursery',
#  '_id': ObjectId('6584a61a8bc4d247f154d10a')}
# {'BusinessName': 'Aylesham Welfare Leisure Centre',
#  '_id': ObjectId('6584a61a8bc4d247f154d11b')}
# {'BusinessName': 'Lucky Star', '_id': ObjectId('6584a61a8bc4d247f154d129')}
# {'BusinessName': 'Naj', '_id': ObjectId('6584a61a8bc4d247f154d12a')}
# {'BusinessName': 'Aylesham Cafe', '_id': ObjectId('6584a61a8bc4d247f154d12b')}
# {'BusinessName': 'Aylesham Butchers',
#  '_id': ObjectId('6584a61a8bc4d247f154d12c')}
# {'BusinessName': 'Osco World Foods',
#  '_id': ObjectId('6584a61a8bc4d247f154d12d')}
# {'BusinessName': '4-5 Market Place',
#  '_id': ObjectId('6584a61a8bc4d247f154d13c')}
# {'BusinessName': 'Roses Tearoom', '_id': ObjectId('6584a61a8bc4d247f154d144')}
# {'BusinessName': 'Sticky Candy', '_id': ObjectId('6584a61a8bc4d247f154d16c')}
# {'BusinessName': 'Countryside Kebab and Pizza',
#  '_id': ObjectId('6584a61a8bc4d247f154d16f')}
# {'BusinessName': 'Londis', '_id': ObjectId('6584a61a8bc4d247f154d171')}
# {'BusinessName': 'Snack Box', '_id': ObjectId('6584a61a8bc4d247f154d176')}
# {'BusinessName': 'Co-op', '_id': ObjectId('6584a61a8bc4d247f154d17c')}
# {'BusinessName': 'Aylesham Fried Chicken',
#  '_id': ObjectId('6584a61a8bc4d247f154d17e')}
# {'BusinessName': 'Cornwallis Fish Bar',
#  '_id': ObjectId('6584a61a8bc4d247f154d17f')}
# {'BusinessName': 'Elevenses', '_id': ObjectId('6584a61a8bc4d247f154d189')}
# {'BusinessName': 'Sunshine Corner Nursery',
#  '_id': ObjectId('6584a61a8bc4d247f154d19a')}
# {'BusinessName': 'Aylesham Breakfast Club',
#  '_id': ObjectId('6584a61a8bc4d247f154d19c')}
# {'BusinessName': 'Aylesham & District Social Club',
#  '_id': ObjectId('6584a61a8bc4d247f154d19d')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('6584a61a8bc4d247f154d1a4')}
# {'BusinessName': "Hill'z treats", '_id': ObjectId('6584a61a8bc4d247f154d1a6')}
# {'BusinessName': 'Jr Farm Meats Ltd',
#  '_id': ObjectId('6584a61a8bc4d247f154d1bb')}
# {'BusinessName': 'The Frog And Orange',
#  '_id': ObjectId('6584a61a8bc4d247f154d1c2')}
# {'BusinessName': 'BMS Cafe', '_id': ObjectId('6584a61a8bc4d247f154d1ce')}
# {'BusinessName': 'Gibsons Farm Shop',
#  '_id': ObjectId('6584a61a8bc4d247f154d1ff')}
# {'BusinessName': 'Crockshard Farm Guest House',
#  '_id': ObjectId('6584a61a8bc4d247f154d207')}
# {'BusinessName': 'Wingham Country Market',
#  '_id': ObjectId('6584a61a8bc4d247f154d210')}
# {'BusinessName': 'Wingham Wildlife Park',
#  '_id': ObjectId('6584a61a8bc4d247f154d240')}
# {'BusinessName': 'Wingham Recreation Club',
#  '_id': ObjectId('6584a61a8bc4d247f154d26e')}
# {'BusinessName': 'Supreme Cuisine', '_id': ObjectId('6584a61a8bc4d247f154d274')}
# {'BusinessName': 'Salma', '_id': ObjectId('6584a61a8bc4d247f154d295')}
# {'BusinessName': 'See-Saw Pre-School',
#  '_id': ObjectId('6584a61a8bc4d247f154d297')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('6584a61a8bc4d247f154d298')}
# {'BusinessName': 'The Anchor Inn', '_id': ObjectId('6584a61a8bc4d247f154d29d')}
# {'BusinessName': 'Wingham After School & Breakfast Clu',
#  '_id': ObjectId('6584a61a8bc4d247f154d29f')}
# {'BusinessName': 'Wingham Newsagents',
#  '_id': ObjectId('6584a61a8bc4d247f154d2a2')}
# {'BusinessName': 'Action Sports Nutrition LLP',
#  '_id': ObjectId('6584a61a8bc4d247f154d2a3')}
# {'BusinessName': 'The Dog at Wingham',
#  '_id': ObjectId('6584a61a8bc4d247f154d2a6')}
# {'BusinessName': 'E T Wilmshurst (Bakery)',
#  '_id': ObjectId('6584a61a8bc4d247f154d2a7')}
# {'BusinessName': 'Oakfield House', '_id': ObjectId('6584a61a8bc4d247f154d2aa')}
# {'BusinessName': 'Covert Cafe', '_id': ObjectId('6584a61a8bc4d247f154d2ab')}
# {'BusinessName': 'Wingham Central Stores',
#  '_id': ObjectId('6584a61a8bc4d247f154d2ad')}
# {'BusinessName': 'Dog And Duck Inn',
#  '_id': ObjectId('6584a61a8bc4d247f154d2b2')}
# {'BusinessName': 'Rising Sun', '_id': ObjectId('6584a61a8bc4d247f154d2b6')}
# {'BusinessName': 'Casino Filling Station',
#  '_id': ObjectId('6584a61a8bc4d247f154d2b8')}
# {'BusinessName': 'Home Cuisine Catering Ltd',
#  '_id': ObjectId('6584a61a8bc4d247f154d2d0')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('6584a61a8bc4d247f154d2d7')}
# {'BusinessName': 'Preston Village Hall',
#  '_id': ObjectId('6584a61a8bc4d247f154d2e1')}
# {'BusinessName': 'Preston Village Stores',
#  '_id': ObjectId('6584a61a8bc4d247f154d2e7')}
# {'BusinessName': 'Preston Family Butchers',
#  '_id': ObjectId('6584a61a8bc4d247f154d2ed')}
# {'BusinessName': 'Coppers Bistro', '_id': ObjectId('6584a61a8bc4d247f154d2f0')}
# {'BusinessName': 'Half Moon And Seven Stars Public House',
#  '_id': ObjectId('6584a61a8bc4d247f154d2f2')}
# {'BusinessName': 'Peacock Events', '_id': ObjectId('6584a61a8bc4d247f154d2f8')}
# {'BusinessName': 'Get Prepped', '_id': ObjectId('6584a61a8bc4d247f154d300')}
# {'BusinessName': 'Marleybrook Weddings',
#  '_id': ObjectId('6584a61a8bc4d247f154d303')}

# %%
# Delete all documents where LocalAuthorityName is "Dover"
db.establishments.delete_many({'LocalAuthorityName': "Dover"})

# %%
# Check if any remaining documents include Dover
# set query variables
query = {'LocalAuthorityName': "Dover"}
count = establishments.count_documents(query)

print(f"The number of documents with LocalAuthorityName as \"Dover\": {count}")
# Out:
# The number of documents with LocalAuthorityName as "Dover": 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': '23 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Ship',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289352,
#  'LocalAuthorityBusinessID': 'PI/000002460',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2015-08-27T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6584a6198bc4d247f154c995'),
#  'geocode': {'latitude': '51.08084', 'longitude': '1.188537'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289352',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},[{"$set": 
    {
        "geocode.latitude": {"$toDouble": "$geocode.latitude"}, 
        "geocode.longitude": {"$toDouble": "$geocode.longitude"}
    }
} ])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{"$set": 
    {
        "RatingValue": {"$toInt": "$RatingValue"}
    }
} ])

# %%
# Check that the coordinates and rating value are now numbers
fields = {"BusinessName":1, "geocode":1, "RatingValue":1}
pprint(establishments.find_one({},fields))
# Out:
# {'BusinessName': 'The Ship',
#  'RatingValue': 5,
#  '_id': ObjectId('6584a6198bc4d247f154c995'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
