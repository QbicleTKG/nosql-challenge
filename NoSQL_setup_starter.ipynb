# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'classDB',
#  'config',
#  'fruits_db',
#  'local',
#  'met',
#  'travel_db',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pines Calyx',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4587.362402580997,
#  'FHRSID': 254250,
#  'LocalAuthorityBusinessID': 'PI/000066174',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DZ',
#  'RatingDate': '2021-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65849d5e2481b1c0b7d8612d'),
#  'geocode': {'latitude': '51.148133', 'longitude': '1.383298'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254250',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
pprint(db.establishments.find_one(new_restaurant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65849d6776e56431e617838d'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields

# set query variables
query = {'BusinessTypeID': 1}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

# run query
results = establishments.find(query, fields)

for i in range(4):
    pprint(results[i])
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65849d5e2481b1c0b7d8612e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65849d5e2481b1c0b7d8612f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65849d5e2481b1c0b7d86130')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65849d5e2481b1c0b7d86131')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeI
db.establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set':
        {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
fields = {"BusinessName":1, "BusinessTypeID":1}
results = establishments.find(query,fields)
for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'Penang Flavours',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65849d6776e56431e617838d')}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"

# set query variables
query = {'LocalAuthorityName': "Dover"}
fields = {'BusinessName': 1}

# run query
results = establishments.find(query, fields)

for result in results:
    pprint(result)
# Out:
# {'BusinessName': 'The Pines Calyx', '_id': ObjectId('65849d5e2481b1c0b7d8612d')}
# {'BusinessName': 'The Tea Room', '_id': ObjectId('65849d5e2481b1c0b7d8612e')}
# {'BusinessName': 'Mrs Knotts Tea Room',
#  '_id': ObjectId('65849d5e2481b1c0b7d8612f')}
# {'BusinessName': 'FirstLight Bar & Café',
#  '_id': ObjectId('65849d5e2481b1c0b7d86130')}
# {'BusinessName': 'Refreshment Kiosk',
#  '_id': ObjectId('65849d5e2481b1c0b7d86131')}
# {'BusinessName': 'The Coastguard Inn',
#  '_id': ObjectId('65849d5e2481b1c0b7d86132')}
# {'BusinessName': 'The Halfway Hut', '_id': ObjectId('65849d5e2481b1c0b7d86133')}
# {'BusinessName': 'The Barn', '_id': ObjectId('65849d5e2481b1c0b7d86134')}
# {'BusinessName': 'Lovetocater', '_id': ObjectId('65849d5e2481b1c0b7d86135')}
# {'BusinessName': 'Lenox House', '_id': ObjectId('65849d5e2481b1c0b7d86136')}
# {'BusinessName': 'Boodles', '_id': ObjectId('65849d5e2481b1c0b7d86137')}
# {'BusinessName': 'Walmer and Kingsdown Golf Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86138')}
# {'BusinessName': 'Portal House School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86139')}
# {'BusinessName': 'The White Cliffs',
#  '_id': ObjectId('65849d5e2481b1c0b7d8613a')}
# {'BusinessName': 'St Margarets At Cliffe C P School',
#  '_id': ObjectId('65849d5e2481b1c0b7d8613b')}
# {'BusinessName': 'The Village Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d8613c')}
# {'BusinessName': 'St Margarets At Cliffe Nursery And After School Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8613d')}
# {'BusinessName': 'The Smugglers', '_id': ObjectId('65849d5e2481b1c0b7d8613e')}
# {'BusinessName': "St Margaret's Bowls and Social Club",
#  '_id': ObjectId('65849d5e2481b1c0b7d8613f')}
# {'BusinessName': 'Boat House & Langdon',
#  '_id': ObjectId('65849d5e2481b1c0b7d86140')}
# {'BusinessName': 'Hogbox', '_id': ObjectId('65849d5e2481b1c0b7d86141')}
# {'BusinessName': 'Goodwins Suite (Reception)',
#  '_id': ObjectId('65849d5e2481b1c0b7d86142')}
# {'BusinessName': 'The Lounge Bar', '_id': ObjectId('65849d5e2481b1c0b7d86143')}
# {'BusinessName': 'Zetland Arms', '_id': ObjectId('65849d5e2481b1c0b7d86144')}
# {'BusinessName': 'Rising Sun', '_id': ObjectId('65849d5e2481b1c0b7d86145')}
# {'BusinessName': 'Seahaven & Kingsdown Lodge',
#  '_id': ObjectId('65849d5e2481b1c0b7d86146')}
# {'BusinessName': 'Oxtale', '_id': ObjectId('65849d5e2481b1c0b7d86147')}
# {'BusinessName': 'Kings Head', '_id': ObjectId('65849d5e2481b1c0b7d86148')}
# {'BusinessName': 'Kingsdown Newsagents',
#  '_id': ObjectId('65849d5e2481b1c0b7d86149')}
# {'BusinessName': 'Kingsdown Pre School',
#  '_id': ObjectId('65849d5e2481b1c0b7d8614a')}
# {'BusinessName': 'National Trust White Cliffs',
#  '_id': ObjectId('65849d5e2481b1c0b7d8614b')}
# {'BusinessName': 'Kingsdown And Ringwould Cofe Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d8614c')}
# {'BusinessName': 'W H Smiths', '_id': ObjectId('65849d5e2481b1c0b7d8614d')}
# {'BusinessName': 'Spirit of France',
#  '_id': ObjectId('65849d5e2481b1c0b7d8614e')}
# {'BusinessName': 'Pride of Canterbury',
#  '_id': ObjectId('65849d5e2481b1c0b7d8614f')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('65849d5e2481b1c0b7d86150')}
# {'BusinessName': 'Burger King', '_id': ObjectId('65849d5e2481b1c0b7d86151')}
# {'BusinessName': 'Spirit of Britain',
#  '_id': ObjectId('65849d5e2481b1c0b7d86152')}
# {'BusinessName': 'Pride of Kent', '_id': ObjectId('65849d5e2481b1c0b7d86153')}
# {'BusinessName': 'Pride of Burgundy',
#  '_id': ObjectId('65849d5e2481b1c0b7d86154')}
# {'BusinessName': 'Kingsdown & Ringwould Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86155')}
# {'BusinessName': 'Delft Seaways', '_id': ObjectId('65849d5e2481b1c0b7d86156')}
# {'BusinessName': 'Dunkerque Seaways',
#  '_id': ObjectId('65849d5e2481b1c0b7d86157')}
# {'BusinessName': 'Dover Cargo Terminal',
#  '_id': ObjectId('65849d5e2481b1c0b7d86158')}
# {'BusinessName': 'Glendale Lodge', '_id': ObjectId('65849d5e2481b1c0b7d86159')}
# {'BusinessName': 'Adventure Backpackers Hostel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8615a')}
# {'BusinessName': 'Dover Seaways', '_id': ObjectId('65849d5e2481b1c0b7d8615b')}
# {'BusinessName': 'Loddington House Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8615c')}
# {'BusinessName': 'Table Table at Premier Inn',
#  '_id': ObjectId('65849d5e2481b1c0b7d8615d')}
# {'BusinessName': 'GCP Catering Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d8615e')}
# {'BusinessName': 'Walmer Castle Tea Rooms',
#  '_id': ObjectId('65849d5e2481b1c0b7d8615f')}
# {'BusinessName': 'Food Outlets', '_id': ObjectId('65849d5e2481b1c0b7d86160')}
# {'BusinessName': 'The Dover Patrol Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d86161')}
# {'BusinessName': 'Places Leisure', '_id': ObjectId('65849d5e2481b1c0b7d86162')}
# {'BusinessName': 'Meadowside Day Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d86163')}
# {'BusinessName': 'Riverside Catering Mobile 10',
#  '_id': ObjectId('65849d5e2481b1c0b7d86164')}
# {'BusinessName': 'Pebbles Kiosk', '_id': ObjectId('65849d5e2481b1c0b7d86165')}
# {'BusinessName': 'Cinque Port Arms',
#  '_id': ObjectId('65849d5e2481b1c0b7d86166')}
# {'BusinessName': 'Abbeyfield House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86167')}
# {'BusinessName': 'Royal Cinque Ports Yacht Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86168')}
# {'BusinessName': 'The Pedaler on the Port',
#  '_id': ObjectId('65849d5e2481b1c0b7d86169')}
# {'BusinessName': 'Port of Dover Cargo Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d8616a')}
# {'BusinessName': 'Pek on the go Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d8616b')}
# {'BusinessName': 'Dover Marina Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8616c')}
# {'BusinessName': 'The Esplanade Kiosk 2',
#  '_id': ObjectId('65849d5e2481b1c0b7d8616d')}
# {'BusinessName': 'Cullins Yard', '_id': ObjectId('65849d5e2481b1c0b7d8616e')}
# {'BusinessName': "Mr White's English Chophouse (DMHS)",
#  '_id': ObjectId('65849d5e2481b1c0b7d8616f')}
# {'BusinessName': 'The Esplanade Kiosk 1',
#  '_id': ObjectId('65849d5e2481b1c0b7d86170')}
# {'BusinessName': 'The Walmer Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d86171')}
# {'BusinessName': 'Bradfield', '_id': ObjectId('65849d5e2481b1c0b7d86172')}
# {'BusinessName': 'Castle House Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86173')}
# {'BusinessName': "Wheeler's Fish & Chips",
#  '_id': ObjectId('65849d5e2481b1c0b7d86174')}
# {'BusinessName': 'Hubert House', '_id': ObjectId('65849d5e2481b1c0b7d86175')}
# {'BusinessName': 'White Horse', '_id': ObjectId('65849d5e2481b1c0b7d86176')}
# {'BusinessName': 'Boardwalk Cafe', '_id': ObjectId('65849d5e2481b1c0b7d86177')}
# {'BusinessName': 'Burger King', '_id': ObjectId('65849d5e2481b1c0b7d86178')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('65849d5e2481b1c0b7d86179')}
# {'BusinessName': 'Nandos', '_id': ObjectId('65849d5e2481b1c0b7d8617a')}
# {'BusinessName': 'Cineworld Cinemas',
#  '_id': ObjectId('65849d5e2481b1c0b7d8617b')}
# {'BusinessName': 'Greggs', '_id': ObjectId('65849d5e2481b1c0b7d8617c')}
# {'BusinessName': 'Travelodge', '_id': ObjectId('65849d5e2481b1c0b7d8617d')}
# {'BusinessName': 'Taco Bell', '_id': ObjectId('65849d5e2481b1c0b7d8617e')}
# {'BusinessName': 'The Booking Hall',
#  '_id': ObjectId('65849d5e2481b1c0b7d8617f')}
# {'BusinessName': 'Superdrug Stores PLC',
#  '_id': ObjectId('65849d5e2481b1c0b7d86180')}
# {'BusinessName': 'Costa Coffee, Next',
#  '_id': ObjectId('65849d5e2481b1c0b7d86181')}
# {'BusinessName': 'Marks and Spencer Dover Simply Food',
#  '_id': ObjectId('65849d5e2481b1c0b7d86182')}
# {'BusinessName': 'Poundland', '_id': ObjectId('65849d5e2481b1c0b7d86183')}
# {'BusinessName': 'The Food Warehouse by Iceland',
#  '_id': ObjectId('65849d5e2481b1c0b7d86184')}
# {'BusinessName': 'Rico Sabor', '_id': ObjectId('65849d5e2481b1c0b7d86185')}
# {'BusinessName': 'Kaspas', '_id': ObjectId('65849d5e2481b1c0b7d86186')}
# {'BusinessName': 'St Anselms Nursing Home',
#  '_id': ObjectId('65849d5e2481b1c0b7d86187')}
# {'BusinessName': 'Cinnamon Island', '_id': ObjectId('65849d5e2481b1c0b7d86188')}
# {'BusinessName': 'Funky Monkey', '_id': ObjectId('65849d5e2481b1c0b7d86189')}
# {'BusinessName': 'Castle Inn', '_id': ObjectId('65849d5e2481b1c0b7d8618a')}
# {'BusinessName': 'The Lord Nelson', '_id': ObjectId('65849d5e2481b1c0b7d8618b')}
# {'BusinessName': 'B 4 9 Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8618c')}
# {'BusinessName': 'Trinity Homes', '_id': ObjectId('65849d5e2481b1c0b7d8618d')}
# {'BusinessName': 'Emmaus Dover Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d8618e')}
# {'BusinessName': 'Holland and Barrett',
#  '_id': ObjectId('65849d5e2481b1c0b7d8618f')}
# {'BusinessName': 'Cleveland Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86190')}
# {'BusinessName': 'IL RUSTICO', '_id': ObjectId('65849d5e2481b1c0b7d86191')}
# {'BusinessName': 'German Doner Kebab',
#  '_id': ObjectId('65849d5e2481b1c0b7d86192')}
# {'BusinessName': 'The Hoptimist Taproom and Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d86193')}
# {'BusinessName': "Rhino & Bull's", '_id': ObjectId('65849d5e2481b1c0b7d86194')}
# {'BusinessName': 'The Duchess', '_id': ObjectId('65849d5e2481b1c0b7d86195')}
# {'BusinessName': 'Number One Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86196')}
# {'BusinessName': 'Rippledown House Environmental Educ',
#  '_id': ObjectId('65849d5e2481b1c0b7d86197')}
# {'BusinessName': 'Terrace Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d86198')}
# {'BusinessName': 'Dover kebab house',
#  '_id': ObjectId('65849d5e2481b1c0b7d86199')}
# {'BusinessName': 'Aspendos', '_id': ObjectId('65849d5e2481b1c0b7d8619a')}
# {'BusinessName': 'Blakes of Dover', '_id': ObjectId('65849d5e2481b1c0b7d8619b')}
# {'BusinessName': 'Dinos Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d8619c')}
# {'BusinessName': 'Castle Take Away Foods',
#  '_id': ObjectId('65849d5e2481b1c0b7d8619d')}
# {'BusinessName': 'Modern Moon Mini Mart',
#  '_id': ObjectId('65849d5e2481b1c0b7d8619e')}
# {'BusinessName': 'Generals Meadow Nursing Home',
#  '_id': ObjectId('65849d5e2481b1c0b7d8619f')}
# {'BusinessName': 'Principals by CH&Co Group ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d861a0')}
# {'BusinessName': 'Xpresso Cafe', '_id': ObjectId('65849d5e2481b1c0b7d861a1')}
# {'BusinessName': 'Market Square Foods Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d861a2')}
# {'BusinessName': 'KFC', '_id': ObjectId('65849d5e2481b1c0b7d861a3')}
# {'BusinessName': 'Oriental Minimart',
#  '_id': ObjectId('65849d5e2481b1c0b7d861a4')}
# {'BusinessName': 'Londis', '_id': ObjectId('65849d5e2481b1c0b7d861a5')}
# {'BusinessName': 'The Elephant & Hind',
#  '_id': ObjectId('65849d5e2481b1c0b7d861a6')}
# {'BusinessName': 'Sunrise Cafe', '_id': ObjectId('65849d5e2481b1c0b7d861a7')}
# {'BusinessName': 'Orient Noodle Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d861a8')}
# {'BusinessName': 'Cafe Gusto', '_id': ObjectId('65849d5e2481b1c0b7d861a9')}
# {'BusinessName': 'BP/Budgens Dover South',
#  '_id': ObjectId('65849d5e2481b1c0b7d861aa')}
# {'BusinessName': 'Dover Masonic Hall',
#  '_id': ObjectId('65849d5e2481b1c0b7d861ab')}
# {'BusinessName': 'Swingate Inn', '_id': ObjectId('65849d5e2481b1c0b7d861ac')}
# {'BusinessName': 'MK Catering', '_id': ObjectId('65849d5e2481b1c0b7d861ad')}
# {'BusinessName': 'Bluebirds', '_id': ObjectId('65849d5e2481b1c0b7d861ae')}
# {'BusinessName': 'Greggs', '_id': ObjectId('65849d5e2481b1c0b7d861af')}
# {'BusinessName': 'Happy Chef', '_id': ObjectId('65849d5e2481b1c0b7d861b0')}
# {'BusinessName': 'Istanbul Kebab House',
#  '_id': ObjectId('65849d5e2481b1c0b7d861b1')}
# {'BusinessName': 'Pizza 2 Night', '_id': ObjectId('65849d5e2481b1c0b7d861b2')}
# {'BusinessName': 'THENU Convenience Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d861b3')}
# {'BusinessName': 'Sonia Lodge', '_id': ObjectId('65849d5e2481b1c0b7d861b4')}
# {'BusinessName': 'The Shake Shop & The Hot Dog Hut',
#  '_id': ObjectId('65849d5e2481b1c0b7d861b5')}
# {'BusinessName': 'Honey Pot Cafe', '_id': ObjectId('65849d5e2481b1c0b7d861b6')}
# {'BusinessName': 'Roman Quay', '_id': ObjectId('65849d5e2481b1c0b7d861b7')}
# {'BusinessName': 'The Market Square Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d861b8')}
# {'BusinessName': 'Dover Convenience Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d861b9')}
# {'BusinessName': 'Discovery Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d861ba')}
# {'BusinessName': 'Chaplins', '_id': ObjectId('65849d5e2481b1c0b7d861bb')}
# {'BusinessName': 'St Marys Parish Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d861bc')}
# {'BusinessName': 'Super Pizza', '_id': ObjectId('65849d5e2481b1c0b7d861bd')}
# {'BusinessName': 'Vinoteq Wine Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d861be')}
# {'BusinessName': 'Walmer Court Farm Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d861bf')}
# {'BusinessName': 'The Attic Bar', '_id': ObjectId('65849d5e2481b1c0b7d861c0')}
# {'BusinessName': 'Five Bells Inn', '_id': ObjectId('65849d5e2481b1c0b7d861c1')}
# {'BusinessName': 'Pizza Shack', '_id': ObjectId('65849d5e2481b1c0b7d861c2')}
# {'BusinessName': 'Subway', '_id': ObjectId('65849d5e2481b1c0b7d861c3')}
# {'BusinessName': 'The Drum Major', '_id': ObjectId('65849d5e2481b1c0b7d861c4')}
# {'BusinessName': 'Best Kebab', '_id': ObjectId('65849d5e2481b1c0b7d861c5')}
# {'BusinessName': 'Laureston House', '_id': ObjectId('65849d5e2481b1c0b7d861c6')}
# {'BusinessName': 'Cafe Melange', '_id': ObjectId('65849d5e2481b1c0b7d861c7')}
# {'BusinessName': 'Eight Bells PH', '_id': ObjectId('65849d5e2481b1c0b7d861c8')}
# {'BusinessName': 'The Knoll Nursing Home/Ami Court',
#  '_id': ObjectId('65849d5e2481b1c0b7d861c9')}
# {'BusinessName': 'Saffron', '_id': ObjectId('65849d5e2481b1c0b7d861ca')}
# {'BusinessName': 'Crystal Garden', '_id': ObjectId('65849d5e2481b1c0b7d861cb')}
# {'BusinessName': 'La Salle Verte', '_id': ObjectId('65849d5e2481b1c0b7d861cc')}
# {'BusinessName': 'The Corner Cafe', '_id': ObjectId('65849d5e2481b1c0b7d861cd')}
# {'BusinessName': 'European Mini Mart',
#  '_id': ObjectId('65849d5e2481b1c0b7d861ce')}
# {'BusinessName': 'Baptist Church', '_id': ObjectId('65849d5e2481b1c0b7d861cf')}
# {'BusinessName': 'Downs Sailing Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d861d0')}
# {'BusinessName': 'Five A Day', '_id': ObjectId('65849d5e2481b1c0b7d861d1')}
# {'BusinessName': 'Walmer Esso', '_id': ObjectId('65849d5e2481b1c0b7d861d2')}
# {'BusinessName': 'Walmer News', '_id': ObjectId('65849d5e2481b1c0b7d861d3')}
# {'BusinessName': 'MFG ESSO WALMER', '_id': ObjectId('65849d5e2481b1c0b7d861d4')}
# {'BusinessName': 'Merkur Slots', '_id': ObjectId('65849d5e2481b1c0b7d861d5')}
# {'BusinessName': 'Wale & Son', '_id': ObjectId('65849d5e2481b1c0b7d861d6')}
# {'BusinessName': 'Lava Lounge Bar', '_id': ObjectId('65849d5e2481b1c0b7d861d7')}
# {'BusinessName': 'Sea Cafe Coffee Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d861d8')}
# {'BusinessName': 'Tummy Station', '_id': ObjectId('65849d5e2481b1c0b7d861d9')}
# {'BusinessName': 'Buzz Bingo', '_id': ObjectId('65849d5e2481b1c0b7d861da')}
# {'BusinessName': 'The Stag', '_id': ObjectId('65849d5e2481b1c0b7d861db')}
# {'BusinessName': 'Walmer Baptist Church',
#  '_id': ObjectId('65849d5e2481b1c0b7d861dc')}
# {'BusinessName': "Stanley's bar & coffee lounge ltd",
#  '_id': ObjectId('65849d5e2481b1c0b7d861dd')}
# {'BusinessName': 'The Duke Of Yorks Brewers Fayre',
#  '_id': ObjectId('65849d5e2481b1c0b7d861de')}
# {'BusinessName': 'Oddfellows Cinque Ports Warden',
#  '_id': ObjectId('65849d5e2481b1c0b7d861df')}
# {'BusinessName': 'Biggin Off Licence',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e0')}
# {'BusinessName': 'Londis (Town & Country Store)',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e1')}
# {'BusinessName': 'B&M Store', '_id': ObjectId('65849d5e2481b1c0b7d861e2')}
# {'BusinessName': 'Burgoyne Heights Pre-School',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e3')}
# {'BusinessName': 'Everest Store', '_id': ObjectId('65849d5e2481b1c0b7d861e4')}
# {'BusinessName': 'Sunnycroft Bed & Breakfast',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e5')}
# {'BusinessName': 'D Gilliver Newsagents',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e6')}
# {'BusinessName': 'The Castle Fish Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e7')}
# {'BusinessName': 'The Haymans Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d861e8')}
# {'BusinessName': "Jane's", '_id': ObjectId('65849d5e2481b1c0b7d861e9')}
# {'BusinessName': 'The Freed Man', '_id': ObjectId('65849d5e2481b1c0b7d861ea')}
# {'BusinessName': 'News in', '_id': ObjectId('65849d5e2481b1c0b7d861eb')}
# {'BusinessName': 'The Beano Cafe', '_id': ObjectId('65849d5e2481b1c0b7d861ec')}
# {'BusinessName': "Goodchild's of Walmer",
#  '_id': ObjectId('65849d5e2481b1c0b7d861ed')}
# {'BusinessName': "Domino's Pizza", '_id': ObjectId('65849d5e2481b1c0b7d861ee')}
# {'BusinessName': 'Dover International',
#  '_id': ObjectId('65849d5e2481b1c0b7d861ef')}
# {'BusinessName': 'Poundland', '_id': ObjectId('65849d5e2481b1c0b7d861f0')}
# {'BusinessName': 'The Thompsons Bell',
#  '_id': ObjectId('65849d5e2481b1c0b7d861f1')}
# {'BusinessName': "Macari's", '_id': ObjectId('65849d5e2481b1c0b7d861f2')}
# {'BusinessName': 'Favorite Chicken & Ribs',
#  '_id': ObjectId('65849d5e2481b1c0b7d861f3')}
# {'BusinessName': 'Boots UK Ltd', '_id': ObjectId('65849d5e2481b1c0b7d861f4')}
# {'BusinessName': 'Maison Dieu Nursery School',
#  '_id': ObjectId('65849d5e2481b1c0b7d861f5')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('65849d5e2481b1c0b7d861f6')}
# {'BusinessName': 'Brunch Cafe Limited',
#  '_id': ObjectId('65849d5e2481b1c0b7d861f7')}
# {'BusinessName': "Amarillo's", '_id': ObjectId('65849d5e2481b1c0b7d861f8')}
# {'BusinessName': 'Bandstand Bakery',
#  '_id': ObjectId('65849d5e2481b1c0b7d861f9')}
# {'BusinessName': 'Dover Soup Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d861fa')}
# {'BusinessName': 'Walmer Fish & Chips',
#  '_id': ObjectId('65849d5e2481b1c0b7d861fb')}
# {'BusinessName': 'The Weigh Inn', '_id': ObjectId('65849d5e2481b1c0b7d861fc')}
# {'BusinessName': 'New China Town', '_id': ObjectId('65849d5e2481b1c0b7d861fd')}
# {'BusinessName': 'Goose on the Green',
#  '_id': ObjectId('65849d5e2481b1c0b7d861fe')}
# {'BusinessName': 'Dover Post Office',
#  '_id': ObjectId('65849d5e2481b1c0b7d861ff')}
# {'BusinessName': 'Dovorian', '_id': ObjectId('65849d5e2481b1c0b7d86200')}
# {'BusinessName': 'Bee Crafty Bee Happy',
#  '_id': ObjectId('65849d5e2481b1c0b7d86201')}
# {'BusinessName': 'Savers', '_id': ObjectId('65849d5e2481b1c0b7d86202')}
# {'BusinessName': 'Maison Dieu Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86203')}
# {'BusinessName': 'Golden Lion', '_id': ObjectId('65849d5e2481b1c0b7d86204')}
# {'BusinessName': 'Shell Budgens Dover',
#  '_id': ObjectId('65849d5e2481b1c0b7d86205')}
# {'BusinessName': 'Pomegranate Pantry and Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d86206')}
# {'BusinessName': 'Bengal Spice', '_id': ObjectId('65849d5e2481b1c0b7d86207')}
# {'BusinessName': 'Palace Fish Bar', '_id': ObjectId('65849d5e2481b1c0b7d86208')}
# {'BusinessName': "Rose's Handmade Cakes",
#  '_id': ObjectId('65849d5e2481b1c0b7d86209')}
# {'BusinessName': 'Save On', '_id': ObjectId('65849d5e2481b1c0b7d8620a')}
# {'BusinessName': 'Age Concern - Dover',
#  '_id': ObjectId('65849d5e2481b1c0b7d8620b')}
# {'BusinessName': 'Deal & Betteshanger  Rugby Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8620c')}
# {'BusinessName': 'The Berry', '_id': ObjectId('65849d5e2481b1c0b7d8620d')}
# {'BusinessName': 'Royal Marines Association',
#  '_id': ObjectId('65849d5e2481b1c0b7d8620e')}
# {'BusinessName': 'Dover Bowling Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8620f')}
# {'BusinessName': 'Gamebase', '_id': ObjectId('65849d5e2481b1c0b7d86210')}
# {'BusinessName': 'Rotherwood Butchers',
#  '_id': ObjectId('65849d5e2481b1c0b7d86211')}
# {'BusinessName': 'The Well Resource Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d86212')}
# {'BusinessName': 'The Lighthouse', '_id': ObjectId('65849d5e2481b1c0b7d86213')}
# {'BusinessName': 'Walmer Chapel', '_id': ObjectId('65849d5e2481b1c0b7d86214')}
# {'BusinessName': 'Thong Dees Thai', '_id': ObjectId('65849d5e2481b1c0b7d86215')}
# {'BusinessName': 'Greggs Bakers', '_id': ObjectId('65849d5e2481b1c0b7d86216')}
# {'BusinessName': 'Dover Sea Angling Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86217')}
# {'BusinessName': 'Prince Albert Public House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86218')}
# {'BusinessName': 'OAKLEYS', '_id': ObjectId('65849d5e2481b1c0b7d86219')}
# {'BusinessName': 'Doyrms Coffee Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d8621a')}
# {'BusinessName': 'St.Edmonds', '_id': ObjectId('65849d5e2481b1c0b7d8621b')}
# {'BusinessName': 'St Albans Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d8621c')}
# {'BusinessName': "Dover's Restover Guest House",
#  '_id': ObjectId('65849d5e2481b1c0b7d8621d')}
# {'BusinessName': 'Norman Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d8621e')}
# {'BusinessName': 'Walmer Care Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d8621f')}
# {'BusinessName': 'Hotel Alma & Cafe Express',
#  '_id': ObjectId('65849d5e2481b1c0b7d86220')}
# {'BusinessName': 'MFG BP Priory Service Station',
#  '_id': ObjectId('65849d5e2481b1c0b7d86221')}
# {'BusinessName': 'Peckish', '_id': ObjectId('65849d5e2481b1c0b7d86222')}
# {'BusinessName': 'Connaught Hotel', '_id': ObjectId('65849d5e2481b1c0b7d86223')}
# {'BusinessName': 'St Stephens Residential Home',
#  '_id': ObjectId('65849d5e2481b1c0b7d86224')}
# {'BusinessName': 'Aycliffe Food & Wine',
#  '_id': ObjectId('65849d5e2481b1c0b7d86225')}
# {'BusinessName': 'Priory Service Station',
#  '_id': ObjectId('65849d5e2481b1c0b7d86226')}
# {'BusinessName': 'Remskeys', '_id': ObjectId('65849d5e2481b1c0b7d86227')}
# {'BusinessName': 'Dover College', '_id': ObjectId('65849d5e2481b1c0b7d86228')}
# {'BusinessName': 'La Scala', '_id': ObjectId('65849d5e2481b1c0b7d86229')}
# {'BusinessName': 'The Academy Dover',
#  '_id': ObjectId('65849d5e2481b1c0b7d8622a')}
# {'BusinessName': 'Dover Town Hall', '_id': ObjectId('65849d5e2481b1c0b7d8622b')}
# {'BusinessName': 'The Malvern Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8622c')}
# {'BusinessName': 'Wellingtons', '_id': ObjectId('65849d5e2481b1c0b7d8622d')}
# {'BusinessName': 'The Park', '_id': ObjectId('65849d5e2481b1c0b7d8622e')}
# {'BusinessName': 'Key Stores', '_id': ObjectId('65849d5e2481b1c0b7d8622f')}
# {'BusinessName': 'Fish Bar & Grill',
#  '_id': ObjectId('65849d5e2481b1c0b7d86230')}
# {'BusinessName': 'Red House', '_id': ObjectId('65849d5e2481b1c0b7d86231')}
# {'BusinessName': 'Whitecliffs Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d86232')}
# {'BusinessName': 'Salisbury House B & B',
#  '_id': ObjectId('65849d5e2481b1c0b7d86233')}
# {'BusinessName': 'Brambles Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86234')}
# {'BusinessName': 'Turkish BBQ & Marina Mexican',
#  '_id': ObjectId('65849d5e2481b1c0b7d86235')}
# {'BusinessName': 'The Fleurs', '_id': ObjectId('65849d5e2481b1c0b7d86236')}
# {'BusinessName': 'Deal Parochial', '_id': ObjectId('65849d5e2481b1c0b7d86237')}
# {'BusinessName': 'Deal Parochial C Of E Aided Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86238')}
# {'BusinessName': 'The Downs C Of E Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86239')}
# {'BusinessName': 'Dover Baptist Church',
#  '_id': ObjectId('65849d5e2481b1c0b7d8623a')}
# {'BusinessName': 'Pizza Pronto', '_id': ObjectId('65849d5e2481b1c0b7d8623b')}
# {'BusinessName': 'Dover Fish Bar', '_id': ObjectId('65849d5e2481b1c0b7d8623c')}
# {'BusinessName': 'St Richards School Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8623d')}
# {'BusinessName': 'Calcutta Port', '_id': ObjectId('65849d5e2481b1c0b7d8623e')}
# {'BusinessName': 'St Richards Roman Catholic Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d8623f')}
# {'BusinessName': 'Momo Hub limited',
#  '_id': ObjectId('65849d5e2481b1c0b7d86240')}
# {'BusinessName': 'Turkish Delight', '_id': ObjectId('65849d5e2481b1c0b7d86241')}
# {'BusinessName': 'Saveon Supermarket',
#  '_id': ObjectId('65849d5e2481b1c0b7d86242')}
# {'BusinessName': 'Priory Hotel', '_id': ObjectId('65849d5e2481b1c0b7d86243')}
# {'BusinessName': 'Number One B & B',
#  '_id': ObjectId('65849d5e2481b1c0b7d86244')}
# {'BusinessName': 'Dover Food & Wine',
#  '_id': ObjectId('65849d5e2481b1c0b7d86245')}
# {'BusinessName': 'Buffers', '_id': ObjectId('65849d5e2481b1c0b7d86246')}
# {'BusinessName': 'Pumpkin Cafe Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d86247')}
# {'BusinessName': 'Guston Church Of England Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86248')}
# {'BusinessName': 'English Heritage Trust',
#  '_id': ObjectId('65849d5e2481b1c0b7d86249')}
# {'BusinessName': 'Community Church Deal',
#  '_id': ObjectId('65849d5e2481b1c0b7d8624a')}
# {'BusinessName': 'The Courtyard Oyster Bar And Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d8624b')}
# {'BusinessName': 'The Flamin Chicken',
#  '_id': ObjectId('65849d5e2481b1c0b7d8624c')}
# {'BusinessName': 'New Moonflower', '_id': ObjectId('65849d5e2481b1c0b7d8624d')}
# {'BusinessName': "Sally Reeve's Cambridge Weight Plan",
#  '_id': ObjectId('65849d5e2481b1c0b7d8624e')}
# {'BusinessName': 'Baba Food and Wine',
#  '_id': ObjectId('65849d5e2481b1c0b7d8624f')}
# {'BusinessName': 'Euro Chicken', '_id': ObjectId('65849d5e2481b1c0b7d86250')}
# {'BusinessName': "Bleriot's House", '_id': ObjectId('65849d5e2481b1c0b7d86251')}
# {'BusinessName': 'Kings Head', '_id': ObjectId('65849d5e2481b1c0b7d86252')}
# {'BusinessName': 'Zazen Kitchen', '_id': ObjectId('65849d5e2481b1c0b7d86253')}
# {'BusinessName': 'Duke of Yorks Royal Military School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86254')}
# {'BusinessName': 'U Babuni', '_id': ObjectId('65849d5e2481b1c0b7d86255')}
# {'BusinessName': 'Dunkerleys Hotel & Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d86256')}
# {'BusinessName': 'The Blue Mermaid Fish Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d86257')}
# {'BusinessName': 'MJ Stores', '_id': ObjectId('65849d5e2481b1c0b7d86258')}
# {'BusinessName': 'The Port Arms', '_id': ObjectId('65849d5e2481b1c0b7d86259')}
# {'BusinessName': 'Homeleigh Residential Care',
#  '_id': ObjectId('65849d5e2481b1c0b7d8625a')}
# {'BusinessName': 'White Cliffs Convenience Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d8625b')}
# {'BusinessName': 'Golden Grill Fish Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d8625c')}
# {'BusinessName': 'HEY! Sushi', '_id': ObjectId('65849d5e2481b1c0b7d8625d')}
# {'BusinessName': 'The Village Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d8625e')}
# {'BusinessName': 'Deal Pier Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d8625f')}
# {'BusinessName': 'Deal Victoria And Barnes Close Cc',
#  '_id': ObjectId('65849d5e2481b1c0b7d86260')}
# {'BusinessName': 'Dylan Palace', '_id': ObjectId('65849d5e2481b1c0b7d86261')}
# {'BusinessName': 'The Taphouse', '_id': ObjectId('65849d5e2481b1c0b7d86262')}
# {'BusinessName': "Hoody's Community Cafe",
#  '_id': ObjectId('65849d5e2481b1c0b7d86263')}
# {'BusinessName': 'Hoodys Community Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d86264')}
# {'BusinessName': 'Walmer Castle', '_id': ObjectId('65849d5e2481b1c0b7d86265')}
# {'BusinessName': 'Hey Hey', '_id': ObjectId('65849d5e2481b1c0b7d86266')}
# {'BusinessName': 'Hog & Bean Deli and Eatery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86267')}
# {'BusinessName': 'Premier Mini Mart',
#  '_id': ObjectId('65849d5e2481b1c0b7d86268')}
# {'BusinessName': 'International Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d86269')}
# {'BusinessName': 'Tastier Treats', '_id': ObjectId('65849d5e2481b1c0b7d8626a')}
# {'BusinessName': 'Icy hog parlour', '_id': ObjectId('65849d5e2481b1c0b7d8626b')}
# {'BusinessName': 'Chicken King', '_id': ObjectId('65849d5e2481b1c0b7d8626c')}
# {'BusinessName': 'Dover Pantry', '_id': ObjectId('65849d5e2481b1c0b7d8626d')}
# {'BusinessName': 'Little Harriettes of Deal',
#  '_id': ObjectId('65849d5e2481b1c0b7d8626e')}
# {'BusinessName': 'The Grapevine cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d8626f')}
# {'BusinessName': 'Iceland', '_id': ObjectId('65849d5e2481b1c0b7d86270')}
# {'BusinessName': 'Cin Cin', '_id': ObjectId('65849d5e2481b1c0b7d86271')}
# {'BusinessName': 'Deal Beach Hut', '_id': ObjectId('65849d5e2481b1c0b7d86272')}
# {'BusinessName': 'Lillyroos', '_id': ObjectId('65849d5e2481b1c0b7d86273')}
# {'BusinessName': 'Luscious Chinese Takeaway',
#  '_id': ObjectId('65849d5e2481b1c0b7d86274')}
# {'BusinessName': 'Marmaris Kebab & Pizza House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86275')}
# {'BusinessName': 'Pop Up Cafe', '_id': ObjectId('65849d5e2481b1c0b7d86276')}
# {'BusinessName': 'Louis Armstrong', '_id': ObjectId('65849d5e2481b1c0b7d86277')}
# {'BusinessName': 'La Friends Pizzeria',
#  '_id': ObjectId('65849d5e2481b1c0b7d86278')}
# {'BusinessName': 'Deal Beach Parlour',
#  '_id': ObjectId('65849d5e2481b1c0b7d86279')}
# {'BusinessName': 'The Lane', '_id': ObjectId('65849d5e2481b1c0b7d8627a')}
# {'BusinessName': 'Wellingtons', '_id': ObjectId('65849d5e2481b1c0b7d8627b')}
# {'BusinessName': 'The Bohemian', '_id': ObjectId('65849d5e2481b1c0b7d8627c')}
# {'BusinessName': 'Cabin Bar, The Clarendon Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8627d')}
# {'BusinessName': 'Sea View', '_id': ObjectId('65849d5e2481b1c0b7d8627e')}
# {'BusinessName': 'Dine India, The Clarendon Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8627f')}
# {'BusinessName': 'Salentinos', '_id': ObjectId('65849d5e2481b1c0b7d86280')}
# {'BusinessName': 'Waterfront Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d86281')}
# {'BusinessName': 'The Thirsty Scarecrow',
#  '_id': ObjectId('65849d5e2481b1c0b7d86282')}
# {'BusinessName': 'Roosters Inn', '_id': ObjectId('65849d5e2481b1c0b7d86283')}
# {'BusinessName': 'Dolphin Kebab', '_id': ObjectId('65849d5e2481b1c0b7d86284')}
# {'BusinessName': 'Pizza Gogo', '_id': ObjectId('65849d5e2481b1c0b7d86285')}
# {'BusinessName': 'The Meatball Company',
#  '_id': ObjectId('65849d5e2481b1c0b7d86286')}
# {'BusinessName': 'Deal Direct Fish & Shellfish',
#  '_id': ObjectId('65849d5e2481b1c0b7d86287')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('65849d5e2481b1c0b7d86288')}
# {'BusinessName': 'Starburger Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d86289')}
# {'BusinessName': 'Kings Coffee Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d8628a')}
# {'BusinessName': 'The Gaiety Bar', '_id': ObjectId('65849d5e2481b1c0b7d8628b')}
# {'BusinessName': 'Aspendos', '_id': ObjectId('65849d5e2481b1c0b7d8628c')}
# {'BusinessName': 'Poundstretcher', '_id': ObjectId('65849d5e2481b1c0b7d8628d')}
# {'BusinessName': 'J J Wood', '_id': ObjectId('65849d5e2481b1c0b7d8628e')}
# {'BusinessName': 'Bartlett and White',
#  '_id': ObjectId('65849d5e2481b1c0b7d8628f')}
# {'BusinessName': 'Poundstretcher', '_id': ObjectId('65849d5e2481b1c0b7d86290')}
# {'BusinessName': 'Asda', '_id': ObjectId('65849d5e2481b1c0b7d86291')}
# {'BusinessName': 'Westbury House', '_id': ObjectId('65849d5e2481b1c0b7d86292')}
# {'BusinessName': 'Farmfoods', '_id': ObjectId('65849d5e2481b1c0b7d86293')}
# {'BusinessName': 'Clare House', '_id': ObjectId('65849d5e2481b1c0b7d86294')}
# {'BusinessName': 'Love Drinks', '_id': ObjectId('65849d5e2481b1c0b7d86295')}
# {'BusinessName': 'Holland & Barrett',
#  '_id': ObjectId('65849d5e2481b1c0b7d86296')}
# {'BusinessName': 'The Just Reproach',
#  '_id': ObjectId('65849d5e2481b1c0b7d86297')}
# {'BusinessName': 'Royal Snooker Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86298')}
# {'BusinessName': 'Star of India', '_id': ObjectId('65849d5e2481b1c0b7d86299')}
# {'BusinessName': 'Route One', '_id': ObjectId('65849d5e2481b1c0b7d8629a')}
# {'BusinessName': 'Strand Coffee House',
#  '_id': ObjectId('65849d5e2481b1c0b7d8629b')}
# {'BusinessName': "Al's Bakery", '_id': ObjectId('65849d5e2481b1c0b7d8629c')}
# {'BusinessName': 'The Lane Bakery', '_id': ObjectId('65849d5e2481b1c0b7d8629d')}
# {'BusinessName': 'Peckish', '_id': ObjectId('65849d5e2481b1c0b7d8629e')}
# {'BusinessName': 'Sir Norman Wisdom',
#  '_id': ObjectId('65849d5e2481b1c0b7d8629f')}
# {'BusinessName': 'Margheritas', '_id': ObjectId('65849d5e2481b1c0b7d862a0')}
# {'BusinessName': 'BonneBombe', '_id': ObjectId('65849d5e2481b1c0b7d862a1')}
# {'BusinessName': 'Royal Hotel', '_id': ObjectId('65849d5e2481b1c0b7d862a2')}
# {'BusinessName': 'Iceland', '_id': ObjectId('65849d5e2481b1c0b7d862a3')}
# {'BusinessName': 'The Goodwin', '_id': ObjectId('65849d5e2481b1c0b7d862a4')}
# {'BusinessName': "Domino's Pizza", '_id': ObjectId('65849d5e2481b1c0b7d862a5')}
# {'BusinessName': 'Smugglers Records',
#  '_id': ObjectId('65849d5e2481b1c0b7d862a6')}
# {'BusinessName': '81 Beach Street', '_id': ObjectId('65849d5e2481b1c0b7d862a7')}
# {'BusinessName': 'Starbucks', '_id': ObjectId('65849d5e2481b1c0b7d862a8')}
# {'BusinessName': 'The Seagull', '_id': ObjectId('65849d5e2481b1c0b7d862a9')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('65849d5e2481b1c0b7d862aa')}
# {'BusinessName': 'McCarthy & Stone - Dover',
#  '_id': ObjectId('65849d5e2481b1c0b7d862ab')}
# {'BusinessName': 'M & Co', '_id': ObjectId('65849d5e2481b1c0b7d862ac')}
# {'BusinessName': "The Meat'in Place",
#  '_id': ObjectId('65849d5e2481b1c0b7d862ad')}
# {'BusinessName': 'Royal British Legion Downs Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d862ae')}
# {'BusinessName': 'Vanes', '_id': ObjectId('65849d5e2481b1c0b7d862af')}
# {'BusinessName': 'Alexander House Care Home',
#  '_id': ObjectId('65849d5e2481b1c0b7d862b0')}
# {'BusinessName': 'Milaad Tandoori Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d862b1')}
# {'BusinessName': 'Poundland', '_id': ObjectId('65849d5e2481b1c0b7d862b2')}
# {'BusinessName': 'Tower Kebab', '_id': ObjectId('65849d5e2481b1c0b7d862b3')}
# {'BusinessName': 'Tower Burgers and Shakes',
#  '_id': ObjectId('65849d5e2481b1c0b7d862b4')}
# {'BusinessName': "Kerry's Bakehouse & Eatery",
#  '_id': ObjectId('65849d5e2481b1c0b7d862b5')}
# {'BusinessName': 'Ocean Rooms', '_id': ObjectId('65849d5e2481b1c0b7d862b6')}
# {'BusinessName': 'The Eagle', '_id': ObjectId('65849d5e2481b1c0b7d862b7')}
# {'BusinessName': 'J C Rook & Sons Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d862b8')}
# {'BusinessName': 'Longfield Local', '_id': ObjectId('65849d5e2481b1c0b7d862b9')}
# {'BusinessName': 'The Dining Club', '_id': ObjectId('65849d5e2481b1c0b7d862ba')}
# {'BusinessName': 'Longfield Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d862bb')}
# {'BusinessName': 'Sandown', '_id': ObjectId('65849d5e2481b1c0b7d862bc')}
# {'BusinessName': 'Mild White', '_id': ObjectId('65849d5e2481b1c0b7d862bd')}
# {'BusinessName': 'Admiral Harvey', '_id': ObjectId('65849d5e2481b1c0b7d862be')}
# {'BusinessName': 'Queen Street Tap',
#  '_id': ObjectId('65849d5e2481b1c0b7d862bf')}
# {'BusinessName': 'Tides Leisure Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d862c0')}
# {'BusinessName': 'Filberts Foods', '_id': ObjectId('65849d5e2481b1c0b7d862c1')}
# {'BusinessName': 'The Original Factory Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d862c2')}
# {'BusinessName': 'Happy Fryer', '_id': ObjectId('65849d5e2481b1c0b7d862c3')}
# {'BusinessName': 'Bridge Street News',
#  '_id': ObjectId('65849d5e2481b1c0b7d862c4')}
# {'BusinessName': 'Frog and Scot', '_id': ObjectId('65849d5e2481b1c0b7d862c5')}
# {'BusinessName': 'Hope & Lane', '_id': ObjectId('65849d5e2481b1c0b7d862c6')}
# {'BusinessName': 'Victuals & Co', '_id': ObjectId('65849d5e2481b1c0b7d862c7')}
# {'BusinessName': 'Your Shop', '_id': ObjectId('65849d5e2481b1c0b7d862c8')}
# {'BusinessName': 'Deal Centre For The Retired',
#  '_id': ObjectId('65849d5e2481b1c0b7d862c9')}
# {'BusinessName': 'The Black Pig', '_id': ObjectId('65849d5e2481b1c0b7d862ca')}
# {'BusinessName': 'Astor Theatre', '_id': ObjectId('65849d5e2481b1c0b7d862cb')}
# {'BusinessName': 'Middle Street Fish Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d862cc')}
# {'BusinessName': 'Soul Chef Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d862cd')}
# {'BusinessName': 'Arno & Co', '_id': ObjectId('65849d5e2481b1c0b7d862ce')}
# {'BusinessName': 'Aldi Stores Ltd', '_id': ObjectId('65849d5e2481b1c0b7d862cf')}
# {'BusinessName': 'The Rose Hotel', '_id': ObjectId('65849d5e2481b1c0b7d862d0')}
# {'BusinessName': 'The Canterbury fruit stalls',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d1')}
# {'BusinessName': 'West Street Mini Market',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d2')}
# {'BusinessName': 'No Name Shop', '_id': ObjectId('65849d5e2481b1c0b7d862d3')}
# {'BusinessName': 'Dover Grammar School For Girls',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d4')}
# {'BusinessName': 'Le Pinardier', '_id': ObjectId('65849d5e2481b1c0b7d862d5')}
# {'BusinessName': 'The Three Compasses',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d6')}
# {'BusinessName': 'The History Project',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d7')}
# {'BusinessName': 'S.Mart Offlicense & Convenience',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d8')}
# {'BusinessName': 'Miretti Pasticceria',
#  '_id': ObjectId('65849d5e2481b1c0b7d862d9')}
# {'BusinessName': 'Eagle Tavern', '_id': ObjectId('65849d5e2481b1c0b7d862da')}
# {'BusinessName': 'Spires Hospitality Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d862db')}
# {'BusinessName': 'Spires Bistro, The Landmark Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d862dc')}
# {'BusinessName': 'The Merchant of Relish',
#  '_id': ObjectId('65849d5e2481b1c0b7d862dd')}
# {'BusinessName': 'Dial-A-Pizza', '_id': ObjectId('65849d5e2481b1c0b7d862de')}
# {'BusinessName': 'Creative Minds Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d862df')}
# {'BusinessName': 'Tea Cafe Restaurant',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e0')}
# {'BusinessName': 'Jenkins & Son', '_id': ObjectId('65849d5e2481b1c0b7d862e1')}
# {'BusinessName': 'Deal Town Rangers Football Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e2')}
# {'BusinessName': 'Goodwin Academy', '_id': ObjectId('65849d5e2481b1c0b7d862e3')}
# {'BusinessName': 'Peppers Healthfoods',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e4')}
# {'BusinessName': 'Treetops Pre School',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e5')}
# {'BusinessName': 'Felbrigg House Residential Home',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e6')}
# {'BusinessName': 'Kaleidascope Childcare Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e7')}
# {'BusinessName': 'Deal Grill', '_id': ObjectId('65849d5e2481b1c0b7d862e8')}
# {'BusinessName': 'Kent Museum of the Moving Image',
#  '_id': ObjectId('65849d5e2481b1c0b7d862e9')}
# {'BusinessName': 'Westbank Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d862ea')}
# {'BusinessName': "Sainsbury's", '_id': ObjectId('65849d5e2481b1c0b7d862eb')}
# {'BusinessName': 'Jerk n Tingz', '_id': ObjectId('65849d5e2481b1c0b7d862ec')}
# {'BusinessName': 'The Daily Grind', '_id': ObjectId('65849d5e2481b1c0b7d862ed')}
# {'BusinessName': 'River Caterers', '_id': ObjectId('65849d5e2481b1c0b7d862ee')}
# {'BusinessName': 'M Smith Butchers',
#  '_id': ObjectId('65849d5e2481b1c0b7d862ef')}
# {'BusinessName': "Bear's Well", '_id': ObjectId('65849d5e2481b1c0b7d862f0')}
# {'BusinessName': 'Direct Pizza Company',
#  '_id': ObjectId('65849d5e2481b1c0b7d862f1')}
# {'BusinessName': 'Tower Hamlets Stores',
#  '_id': ObjectId('65849d5e2481b1c0b7d862f2')}
# {'BusinessName': 'Park Convenience Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d862f3')}
# {'BusinessName': "Welly's Coffeehouse and Bar",
#  '_id': ObjectId('65849d5e2481b1c0b7d862f4')}
# {'BusinessName': 'Sweetzuk', '_id': ObjectId('65849d5e2481b1c0b7d862f5')}
# {'BusinessName': "Welly's Coffee House & Bar",
#  '_id': ObjectId('65849d5e2481b1c0b7d862f6')}
# {'BusinessName': "Bloody Mary's", '_id': ObjectId('65849d5e2481b1c0b7d862f7')}
# {'BusinessName': 'Mileage', '_id': ObjectId('65849d5e2481b1c0b7d862f8')}
# {'BusinessName': 'The Bar', '_id': ObjectId('65849d5e2481b1c0b7d862f9')}
# {'BusinessName': 'Dewdrop Inn', '_id': ObjectId('65849d5e2481b1c0b7d862fa')}
# {'BusinessName': 'Trinity Church', '_id': ObjectId('65849d5e2481b1c0b7d862fb')}
# {'BusinessName': "Brenda's Kitchen",
#  '_id': ObjectId('65849d5e2481b1c0b7d862fc')}
# {'BusinessName': 'Top Wok', '_id': ObjectId('65849d5e2481b1c0b7d862fd')}
# {'BusinessName': 'Ship Inn', '_id': ObjectId('65849d5e2481b1c0b7d862fe')}
# {'BusinessName': 'Flints', '_id': ObjectId('65849d5e2481b1c0b7d862ff')}
# {'BusinessName': 'The Salvation Army',
#  '_id': ObjectId('65849d5e2481b1c0b7d86300')}
# {'BusinessName': 'Co-op', '_id': ObjectId('65849d5e2481b1c0b7d86301')}
# {'BusinessName': "Sid's ice cream and donut parlour",
#  '_id': ObjectId('65849d5e2481b1c0b7d86302')}
# {'BusinessName': 'St Edmunds Catholic School Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d86303')}
# {'BusinessName': 'Charlton Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86304')}
# {'BusinessName': 'Deal Welfare Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86305')}
# {'BusinessName': 'Vale View County Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86306')}
# {'BusinessName': 'Priory Fields School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86307')}
# {'BusinessName': 'The Alma', '_id': ObjectId('65849d5e2481b1c0b7d86308')}
# {'BusinessName': 'Deal Bowling Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86309')}
# {'BusinessName': 'Priory Fields School Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8630a')}
# {'BusinessName': 'Prince Albert', '_id': ObjectId('65849d5e2481b1c0b7d8630b')}
# {'BusinessName': 'Deal Hoy', '_id': ObjectId('65849d5e2481b1c0b7d8630c')}
# {'BusinessName': 'Total Fitness Mix Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d8630d')}
# {'BusinessName': 'Spindrift Cafe', '_id': ObjectId('65849d5e2481b1c0b7d8630e')}
# {'BusinessName': 'Peking Palace', '_id': ObjectId('65849d5e2481b1c0b7d8630f')}
# {'BusinessName': 'Mill Shop', '_id': ObjectId('65849d5e2481b1c0b7d86310')}
# {'BusinessName': 'Greggs', '_id': ObjectId('65849d5e2481b1c0b7d86311')}
# {'BusinessName': 'MFG Deal Service Station',
#  '_id': ObjectId('65849d5e2481b1c0b7d86312')}
# {'BusinessName': 'Co-op', '_id': ObjectId('65849d5e2481b1c0b7d86313')}
# {'BusinessName': 'Golden Fillet', '_id': ObjectId('65849d5e2481b1c0b7d86314')}
# {'BusinessName': 'The Boba Dragon', '_id': ObjectId('65849d5e2481b1c0b7d86315')}
# {'BusinessName': 'BP/Budgens Deal', '_id': ObjectId('65849d5e2481b1c0b7d86316')}
# {'BusinessName': 'Brook Lodge', '_id': ObjectId('65849d5e2481b1c0b7d86317')}
# {'BusinessName': 'Magic Chef', '_id': ObjectId('65849d5e2481b1c0b7d86318')}
# {'BusinessName': 'Deal Angling Club 1919',
#  '_id': ObjectId('65849d5e2481b1c0b7d86319')}
# {'BusinessName': 'The Mill Inn', '_id': ObjectId('65849d5e2481b1c0b7d8631a')}
# {'BusinessName': 'Good Choice', '_id': ObjectId('65849d5e2481b1c0b7d8631b')}
# {'BusinessName': 'White Cliffs Tandoori',
#  '_id': ObjectId('65849d5e2481b1c0b7d8631c')}
# {'BusinessName': 'Kent Bakery Co', '_id': ObjectId('65849d5e2481b1c0b7d8631d')}
# {'BusinessName': 'Pizza Plus', '_id': ObjectId('65849d5e2481b1c0b7d8631e')}
# {'BusinessName': 'Spar', '_id': ObjectId('65849d5e2481b1c0b7d8631f')}
# {'BusinessName': 'Star Pizza', '_id': ObjectId('65849d5e2481b1c0b7d86320')}
# {'BusinessName': "Tony's Fish Bar", '_id': ObjectId('65849d5e2481b1c0b7d86321')}
# {'BusinessName': 'Pizza Sprint', '_id': ObjectId('65849d5e2481b1c0b7d86322')}
# {'BusinessName': 'Kong Sing', '_id': ObjectId('65849d5e2481b1c0b7d86323')}
# {'BusinessName': 'St Richards Church Hall Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d86324')}
# {'BusinessName': 'Foresters Inn', '_id': ObjectId('65849d5e2481b1c0b7d86325')}
# {'BusinessName': 'Saracens Head', '_id': ObjectId('65849d5e2481b1c0b7d86326')}
# {'BusinessName': 'Deal Walmer & Kingsdown Rowing Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86327')}
# {'BusinessName': 'Co-op', '_id': ObjectId('65849d5e2481b1c0b7d86328')}
# {'BusinessName': 'Brunch Box', '_id': ObjectId('65849d5e2481b1c0b7d86329')}
# {'BusinessName': 'Friendship Lunch',
#  '_id': ObjectId('65849d5e2481b1c0b7d8632a')}
# {'BusinessName': 'Win Win Chinese Takeaway',
#  '_id': ObjectId('65849d5e2481b1c0b7d8632b')}
# {'BusinessName': 'Boars Head', '_id': ObjectId('65849d5e2481b1c0b7d8632c')}
# {'BusinessName': 'Afyon', '_id': ObjectId('65849d5e2481b1c0b7d8632d')}
# {'BusinessName': 'Ocean Fish and Chips',
#  '_id': ObjectId('65849d5e2481b1c0b7d8632e')}
# {'BusinessName': 'Newsmarket', '_id': ObjectId('65849d5e2481b1c0b7d8632f')}
# {'BusinessName': 'Next Steps Pre-school',
#  '_id': ObjectId('65849d5e2481b1c0b7d86330')}
# {'BusinessName': 'Oasis Chinese Take-Away',
#  '_id': ObjectId('65849d5e2481b1c0b7d86331')}
# {'BusinessName': 'London Kebab House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86332')}
# {'BusinessName': 'Crown and Sceptre',
#  '_id': ObjectId('65849d5e2481b1c0b7d86333')}
# {'BusinessName': 'Barton Junior School Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86334')}
# {'BusinessName': "Dover Working Man's Club & Institute",
#  '_id': ObjectId('65849d5e2481b1c0b7d86335')}
# {'BusinessName': 'Little India', '_id': ObjectId('65849d5e2481b1c0b7d86336')}
# {'BusinessName': 'Mace', '_id': ObjectId('65849d5e2481b1c0b7d86337')}
# {'BusinessName': 'Tesco', '_id': ObjectId('65849d5e2481b1c0b7d86338')}
# {'BusinessName': 'Barton County Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86339')}
# {'BusinessName': 'Fryer Tuck', '_id': ObjectId('65849d5e2481b1c0b7d8633a')}
# {'BusinessName': 'New Century Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d8633b')}
# {'BusinessName': 'Deal Christian Fellowship Trust',
#  '_id': ObjectId('65849d5e2481b1c0b7d8633c')}
# {'BusinessName': 'Langdon School Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8633d')}
# {'BusinessName': 'Old Lantern Inn', '_id': ObjectId('65849d5e2481b1c0b7d8633e')}
# {'BusinessName': 'Whole School Meals',
#  '_id': ObjectId('65849d5e2481b1c0b7d8633f')}
# {'BusinessName': 'Nirja Convenience Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d86340')}
# {'BusinessName': 'Li-Hao', '_id': ObjectId('65849d5e2481b1c0b7d86341')}
# {'BusinessName': 'Key Stores', '_id': ObjectId('65849d5e2481b1c0b7d86342')}
# {'BusinessName': 'Oriental Express',
#  '_id': ObjectId('65849d5e2481b1c0b7d86343')}
# {'BusinessName': 'Londis T/A Right Choice',
#  '_id': ObjectId('65849d5e2481b1c0b7d86344')}
# {'BusinessName': 'Kent Community Health Foundation',
#  '_id': ObjectId('65849d5e2481b1c0b7d86345')}
# {'BusinessName': 'Rainbow Preschool',
#  '_id': ObjectId('65849d5e2481b1c0b7d86346')}
# {'BusinessName': 'Clay Pigeon Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86347')}
# {'BusinessName': 'Chance Inn', '_id': ObjectId('65849d5e2481b1c0b7d86348')}
# {'BusinessName': 'Deal Town Football Supporters Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86349')}
# {'BusinessName': 'Londis Stores', '_id': ObjectId('65849d5e2481b1c0b7d8634a')}
# {'BusinessName': "Trudella's", '_id': ObjectId('65849d5e2481b1c0b7d8634b')}
# {'BusinessName': 'Ann and Pams Florist',
#  '_id': ObjectId('65849d5e2481b1c0b7d8634c')}
# {'BusinessName': 'The Sportsman', '_id': ObjectId('65849d5e2481b1c0b7d8634d')}
# {'BusinessName': 'Aldi', '_id': ObjectId('65849d5e2481b1c0b7d8634e')}
# {'BusinessName': 'Skylight Cafe', '_id': ObjectId('65849d5e2481b1c0b7d8634f')}
# {'BusinessName': 'White Cliffs Bakery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86350')}
# {'BusinessName': "Engel's Paradise (Bistro)",
#  '_id': ObjectId('65849d5e2481b1c0b7d86351')}
# {'BusinessName': 'Cameron Lodge', '_id': ObjectId('65849d5e2481b1c0b7d86352')}
# {'BusinessName': 'One Church Dover',
#  '_id': ObjectId('65849d5e2481b1c0b7d86353')}
# {'BusinessName': 'Sandown School', '_id': ObjectId('65849d5e2481b1c0b7d86354')}
# {'BusinessName': 'Breakwater Mobile Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d86355')}
# {'BusinessName': 'Sutherland House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86356')}
# {'BusinessName': 'St Martins County Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86357')}
# {'BusinessName': 'Tennessee Fried Chicken',
#  '_id': ObjectId('65849d5e2481b1c0b7d86358')}
# {'BusinessName': 'Bowling Green Tavern',
#  '_id': ObjectId('65849d5e2481b1c0b7d86359')}
# {'BusinessName': 'St Martins School Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8635a')}
# {'BusinessName': 'Breakwater Tap House and Pizzeria',
#  '_id': ObjectId('65849d5e2481b1c0b7d8635b')}
# {'BusinessName': 'Linwood Under Fives Preschool',
#  '_id': ObjectId('65849d5e2481b1c0b7d8635c')}
# {'BusinessName': 'The Smugglers Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d8635d')}
# {'BusinessName': 'League Of Friends Of Dover Hospitals',
#  '_id': ObjectId('65849d5e2481b1c0b7d8635e')}
# {'BusinessName': 'Tiny Turtles Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d8635f')}
# {'BusinessName': 'Magnet House', '_id': ObjectId('65849d5e2481b1c0b7d86360')}
# {'BusinessName': 'Happy Feet Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86361')}
# {'BusinessName': "Daisy's Kitchen", '_id': ObjectId('65849d5e2481b1c0b7d86362')}
# {'BusinessName': 'The Farrier Freehouse',
#  '_id': ObjectId('65849d5e2481b1c0b7d86363')}
# {'BusinessName': 'Betteshanger Social Welfare Sports C',
#  '_id': ObjectId('65849d5e2481b1c0b7d86364')}
# {'BusinessName': 'Yummy Takeaway', '_id': ObjectId('65849d5e2481b1c0b7d86365')}
# {'BusinessName': 'The Diamond', '_id': ObjectId('65849d5e2481b1c0b7d86366')}
# {'BusinessName': 'Dover Grammar School For Boys',
#  '_id': ObjectId('65849d5e2481b1c0b7d86367')}
# {'BusinessName': 'King Edward Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d86368')}
# {'BusinessName': "Kelly's Snacks", '_id': ObjectId('65849d5e2481b1c0b7d86369')}
# {'BusinessName': 'Ice Cream Van B30HW',
#  '_id': ObjectId('65849d5e2481b1c0b7d8636a')}
# ...
# {'BusinessName': 'Luigis', '_id': ObjectId('65849d5e2481b1c0b7d86777')}
# {'BusinessName': 'Namaste Sandwich',
#  '_id': ObjectId('65849d5e2481b1c0b7d86779')}
# {'BusinessName': 'Di Vino', '_id': ObjectId('65849d5e2481b1c0b7d8677b')}
# {'BusinessName': 'St Barts Day Nurseries Out Of School Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d8677e')}
# {'BusinessName': 'Sids ice cream and donut parlour',
#  '_id': ObjectId('65849d5e2481b1c0b7d8677f')}
# {'BusinessName': 'The Deep Blue', '_id': ObjectId('65849d5e2481b1c0b7d86780')}
# {'BusinessName': 'Sandwich County Junior School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86786')}
# {'BusinessName': 'Bell Hotel', '_id': ObjectId('65849d5e2481b1c0b7d8678b')}
# {'BusinessName': 'The Admiral Owen',
#  '_id': ObjectId('65849d5e2481b1c0b7d8678f')}
# {'BusinessName': 'Crispin Inn', '_id': ObjectId('65849d5e2481b1c0b7d86794')}
# {'BusinessName': 'Sandwich Wildlife Park Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d86796')}
# {'BusinessName': 'Sandwich Wildlife Park',
#  '_id': ObjectId('65849d5e2481b1c0b7d86797')}
# {'BusinessName': 'My Happy Place Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d86798')}
# {'BusinessName': 'The Haven', '_id': ObjectId('65849d5e2481b1c0b7d86799')}
# {'BusinessName': 'Sandwich Kebab  Pizza',
#  '_id': ObjectId('65849d5e2481b1c0b7d8679a')}
# {'BusinessName': 'Sandwich Convenience Store',
#  '_id': ObjectId('65849d5e2481b1c0b7d8679b')}
# {'BusinessName': 'The Sandwich Bakery Company',
#  '_id': ObjectId('65849d5e2481b1c0b7d8679e')}
# {'BusinessName': 'St Peters B&B', '_id': ObjectId('65849d5e2481b1c0b7d867a1')}
# {'BusinessName': 'Goats That Dance',
#  '_id': ObjectId('65849d5e2481b1c0b7d867a2')}
# {'BusinessName': 'Costa Coffee', '_id': ObjectId('65849d5e2481b1c0b7d867a7')}
# {'BusinessName': 'Friendship Lunch Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d867a8')}
# {'BusinessName': 'Al Taco', '_id': ObjectId('65849d5e2481b1c0b7d867a9')}
# {'BusinessName': 'Five Bells', '_id': ObjectId('65849d5e2481b1c0b7d867aa')}
# {'BusinessName': 'Tan-Bueno', '_id': ObjectId('65849d5e2481b1c0b7d867ac')}
# {'BusinessName': 'The Toll Bridge', '_id': ObjectId('65849d5e2481b1c0b7d867ad')}
# {'BusinessName': 'Eastry Fish Bar', '_id': ObjectId('65849d5e2481b1c0b7d867b1')}
# {'BusinessName': 'No Name Shop and Bistro',
#  '_id': ObjectId('65849d5e2481b1c0b7d867b4')}
# {'BusinessName': 'The Sandwich Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d867b5')}
# {'BusinessName': 'Age Concern Sandwich',
#  '_id': ObjectId('65849d5e2481b1c0b7d867b6')}
# {'BusinessName': 'Spar', '_id': ObjectId('65849d5e2481b1c0b7d867b7')}
# {'BusinessName': 'The Waiting Room',
#  '_id': ObjectId('65849d5e2481b1c0b7d867b8')}
# {'BusinessName': 'Brambles Bed and Breakfast',
#  '_id': ObjectId('65849d5e2481b1c0b7d867ba')}
# {'BusinessName': 'My Thai Ltd', '_id': ObjectId('65849d5e2481b1c0b7d867bb')}
# {'BusinessName': 'Bella Amalfi', '_id': ObjectId('65849d5e2481b1c0b7d867bf')}
# {'BusinessName': 'Smugglers Beer and Music Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d867c0')}
# {'BusinessName': 'Ossies Fish & Chips',
#  '_id': ObjectId('65849d5e2481b1c0b7d867c3')}
# {'BusinessName': 'Woodpecker Court Youth Activities',
#  '_id': ObjectId('65849d5e2481b1c0b7d867c4')}
# {'BusinessName': 'The Market Inn', '_id': ObjectId('65849d5e2481b1c0b7d867c6')}
# {'BusinessName': 'Fleur De Lis', '_id': ObjectId('65849d5e2481b1c0b7d867c8')}
# {'BusinessName': 'The Strand Street Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d867c9')}
# {'BusinessName': "The Sunflower Children's Centre",
#  '_id': ObjectId('65849d5e2481b1c0b7d867cd')}
# {'BusinessName': 'Tots R Us Preschool',
#  '_id': ObjectId('65849d5e2481b1c0b7d867cf')}
# {'BusinessName': 'Visitor Information Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d867d0')}
# {'BusinessName': 'Nourish Contract Catering Group@',
#  '_id': ObjectId('65849d5e2481b1c0b7d867d1')}
# {'BusinessName': 'The Smokehouse', '_id': ObjectId('65849d5e2481b1c0b7d867d2')}
# {'BusinessName': 'Mermaids Locker', '_id': ObjectId('65849d5e2481b1c0b7d867d5')}
# {'BusinessName': 'The Sandwich Sausage Company',
#  '_id': ObjectId('65849d5e2481b1c0b7d867d6')}
# {'BusinessName': 'Eythorne Elvington Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d867d7')}
# {'BusinessName': 'Amigos', '_id': ObjectId('65849d5e2481b1c0b7d867d8')}
# {'BusinessName': 'India Village Tandoori',
#  '_id': ObjectId('65849d5e2481b1c0b7d867d9')}
# {'BusinessName': 'Tilmanstone Colliery Sports Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d867da')}
# {'BusinessName': 'Merry Go Round Pre School',
#  '_id': ObjectId('65849d5e2481b1c0b7d867e0')}
# {'BusinessName': 'Chutney Masala', '_id': ObjectId('65849d5e2481b1c0b7d867e1')}
# {'BusinessName': 'First Choice', '_id': ObjectId('65849d5e2481b1c0b7d867e2')}
# {'BusinessName': 'Optima Care Ltd', '_id': ObjectId('65849d5e2481b1c0b7d867e4')}
# {'BusinessName': 'Eastry Village Supermarket',
#  '_id': ObjectId('65849d5e2481b1c0b7d867e5')}
# {'BusinessName': 'S and C Baitup Family Butcher',
#  '_id': ObjectId('65849d5e2481b1c0b7d867e6')}
# {'BusinessName': 'Red Cow Inn', '_id': ObjectId('65849d5e2481b1c0b7d867e9')}
# {'BusinessName': 'The New Inn', '_id': ObjectId('65849d5e2481b1c0b7d867eb')}
# {'BusinessName': 'Hays Shack', '_id': ObjectId('65849d5e2481b1c0b7d867ec')}
# {'BusinessName': 'Bakers Dozen', '_id': ObjectId('65849d5e2481b1c0b7d867ee')}
# {'BusinessName': 'The Empire Cinema',
#  '_id': ObjectId('65849d5e2481b1c0b7d867fc')}
# {'BusinessName': 'Co-op', '_id': ObjectId('65849d5e2481b1c0b7d867fe')}
# {'BusinessName': 'Bickers', '_id': ObjectId('65849d5e2481b1c0b7d86803')}
# {'BusinessName': 'Java Restaurant', '_id': ObjectId('65849d5e2481b1c0b7d8680b')}
# {'BusinessName': 'Java 2 Go', '_id': ObjectId('65849d5e2481b1c0b7d8680c')}
# {'BusinessName': 'Kings Arms Hotel',
#  '_id': ObjectId('65849d5e2481b1c0b7d8681c')}
# {'BusinessName': 'ECF', '_id': ObjectId('65849d5e2481b1c0b7d86822')}
# {'BusinessName': 'Sandwich Infant School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86826')}
# {'BusinessName': 'Bubbles Nursery And Out Of School Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86828')}
# {'BusinessName': 'Eastry Church Of England Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86830')}
# {'BusinessName': 'The Creative Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d8683b')}
# {'BusinessName': 'Elvington Village Stores',
#  '_id': ObjectId('65849d5e2481b1c0b7d86844')}
# {'BusinessName': 'Elvington Masala',
#  '_id': ObjectId('65849d5e2481b1c0b7d86845')}
# {'BusinessName': 'Golden Kitchen', '_id': ObjectId('65849d5e2481b1c0b7d8684c')}
# {'BusinessName': 'Bell Inn', '_id': ObjectId('65849d5e2481b1c0b7d86858')}
# {'BusinessName': 'Elvington & Eythorne Heritage Group',
#  '_id': ObjectId('65849d5e2481b1c0b7d86866')}
# {'BusinessName': 'Nourish Contract Catering Group@',
#  '_id': ObjectId('65849d5e2481b1c0b7d8686b')}
# {'BusinessName': 'Sibertswold School Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d8686c')}
# {'BusinessName': 'Travelodge Sandwich',
#  '_id': ObjectId('65849d5e2481b1c0b7d86887')}
# {'BusinessName': 'LEON', '_id': ObjectId('65849d5e2481b1c0b7d8689b')}
# {'BusinessName': 'The Field Kitchen',
#  '_id': ObjectId('65849d5e2481b1c0b7d868a4')}
# {'BusinessName': 'White Mill Farm Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d868a6')}
# {'BusinessName': 'Brambling House', '_id': ObjectId('65849d5e2481b1c0b7d868b7')}
# {'BusinessName': 'T42 Community Cafe',
#  '_id': ObjectId('65849d5e2481b1c0b7d868b9')}
# {'BusinessName': 'The Oast B&B', '_id': ObjectId('65849d5e2481b1c0b7d868ba')}
# {'BusinessName': 'Brambling Lodge Residential Home',
#  '_id': ObjectId('65849d5e2481b1c0b7d868bb')}
# {'BusinessName': 'Co-op', '_id': ObjectId('65849d5e2481b1c0b7d868bf')}
# {'BusinessName': 'Colonels Cafe', '_id': ObjectId('65849d5e2481b1c0b7d868c6')}
# {'BusinessName': 'Baypoint Sandwich',
#  '_id': ObjectId('65849d5e2481b1c0b7d868ee')}
# {'BusinessName': 'Pegwell Bay Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d868f0')}
# {'BusinessName': 'Able Catering', '_id': ObjectId('65849d5e2481b1c0b7d868f3')}
# {'BusinessName': 'Premier Stores', '_id': ObjectId('65849d5e2481b1c0b7d868f8')}
# {'BusinessName': 'Subway', '_id': ObjectId('65849d5e2481b1c0b7d86908')}
# {'BusinessName': 'Kfc', '_id': ObjectId('65849d5e2481b1c0b7d86910')}
# {'BusinessName': 'Richborough Service Station',
#  '_id': ObjectId('65849d5e2481b1c0b7d86912')}
# {'BusinessName': 'Knowlton Court', '_id': ObjectId('65849d5e2481b1c0b7d86926')}
# {'BusinessName': 'C&S Catering (2)',
#  '_id': ObjectId('65849d5e2481b1c0b7d86956')}
# {'BusinessName': 'C&S Catering (1)',
#  '_id': ObjectId('65849d5e2481b1c0b7d86957')}
# {'BusinessName': 'Goss Hall', '_id': ObjectId('65849d5e2481b1c0b7d869cb')}
# {'BusinessName': 'Griffins Head', '_id': ObjectId('65849d5e2481b1c0b7d869d4')}
# {'BusinessName': 'King Edward House',
#  '_id': ObjectId('65849d5e2481b1c0b7d869d5')}
# {'BusinessName': 'The Royal Oak', '_id': ObjectId('65849d5e2481b1c0b7d869e5')}
# {'BusinessName': 'Black Pig', '_id': ObjectId('65849d5e2481b1c0b7d86a36')}
# {'BusinessName': 'Nonington Church Of England Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86a56')}
# {'BusinessName': 'Ash Village Hall',
#  '_id': ObjectId('65849d5e2481b1c0b7d86a61')}
# {'BusinessName': 'Nonington Farms Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d86a62')}
# {'BusinessName': 'Welcome', '_id': ObjectId('65849d5e2481b1c0b7d86a6f')}
# {'BusinessName': 'Staple Pre School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86a7a')}
# {'BusinessName': 'Number 37', '_id': ObjectId('65849d5e2481b1c0b7d86a7f')}
# {'BusinessName': "Juliet's Farm Shop and Cafe",
#  '_id': ObjectId('65849d5e2481b1c0b7d86a85')}
# {'BusinessName': 'The Chequer Inn', '_id': ObjectId('65849d5e2481b1c0b7d86a8e')}
# {'BusinessName': 'St Faiths At Ash School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86a9b')}
# {'BusinessName': 'Ash Pizza King', '_id': ObjectId('65849d5e2481b1c0b7d86a9d')}
# {'BusinessName': 'Poparound', '_id': ObjectId('65849d5e2481b1c0b7d86a9e')}
# {'BusinessName': 'The Volunteer PH',
#  '_id': ObjectId('65849d5e2481b1c0b7d86ab0')}
# {'BusinessName': 'Fledglings Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86ad2')}
# {'BusinessName': 'Cartwright & Kelsey Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86ad3')}
# {'BusinessName': 'Jackdaw Inn', '_id': ObjectId('65849d5e2481b1c0b7d86ae2')}
# {'BusinessName': 'Cartwright And Kelsey Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86aed')}
# {'BusinessName': 'Goldstone Butchers',
#  '_id': ObjectId('65849d5e2481b1c0b7d86afd')}
# {'BusinessName': 'The Curing Shed', '_id': ObjectId('65849d5e2481b1c0b7d86afe')}
# {'BusinessName': 'B And B Accommodation',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b06')}
# {'BusinessName': 'Fitzwalter Arms', '_id': ObjectId('65849d5e2481b1c0b7d86b65')}
# {'BusinessName': 'Bennett & Friends Catering + Events',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b74')}
# {'BusinessName': 'Bechange', '_id': ObjectId('65849d5e2481b1c0b7d86b75')}
# {'BusinessName': 'The Old Dairy', '_id': ObjectId('65849d5e2481b1c0b7d86b79')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b7c')}
# {'BusinessName': 'Cooked with Love',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b7d')}
# {'BusinessName': 'Goodnestone Park',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b7e')}
# {'BusinessName': 'Kaleidoscope Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b81')}
# {'BusinessName': 'St Josephs Roman Catholic Primary School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b86')}
# {'BusinessName': 'Aylesham And Snowdowns Bowls Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b89')}
# {'BusinessName': 'Aylesham Welfare Leisure Centre',
#  '_id': ObjectId('65849d5e2481b1c0b7d86b9e')}
# {'BusinessName': 'Naj', '_id': ObjectId('65849d5e2481b1c0b7d86ba5')}
# {'BusinessName': '4-5 Market Place',
#  '_id': ObjectId('65849d5e2481b1c0b7d86ba9')}
# {'BusinessName': 'Aylesham Cafe', '_id': ObjectId('65849d5e2481b1c0b7d86bab')}
# {'BusinessName': 'Aylesham Butchers',
#  '_id': ObjectId('65849d5e2481b1c0b7d86bac')}
# {'BusinessName': 'Lucky Star', '_id': ObjectId('65849d5e2481b1c0b7d86bae')}
# {'BusinessName': 'Osco World Foods',
#  '_id': ObjectId('65849d5e2481b1c0b7d86bb0')}
# {'BusinessName': 'Roses Tearoom', '_id': ObjectId('65849d5e2481b1c0b7d86bb7')}
# {'BusinessName': 'Snack Box', '_id': ObjectId('65849d5e2481b1c0b7d86be7')}
# {'BusinessName': 'Co-op', '_id': ObjectId('65849d5e2481b1c0b7d86bef')}
# {'BusinessName': 'Londis', '_id': ObjectId('65849d5e2481b1c0b7d86bf0')}
# {'BusinessName': 'Countryside Kebab and Pizza',
#  '_id': ObjectId('65849d5e2481b1c0b7d86bf1')}
# {'BusinessName': 'Sticky Candy', '_id': ObjectId('65849d5e2481b1c0b7d86bf3')}
# {'BusinessName': 'Cornwallis Fish Bar',
#  '_id': ObjectId('65849d5e2481b1c0b7d86bf9')}
# {'BusinessName': 'Aylesham Fried Chicken',
#  '_id': ObjectId('65849d5e2481b1c0b7d86bfc')}
# {'BusinessName': 'Elevenses', '_id': ObjectId('65849d5e2481b1c0b7d86c0d')}
# {'BusinessName': 'Aylesham & District Social Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c17')}
# {'BusinessName': 'Aylesham Breakfast Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c1d')}
# {'BusinessName': 'Sunshine Corner Nursery',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c1e')}
# {'BusinessName': "Hill'z treats", '_id': ObjectId('65849d5e2481b1c0b7d86c27')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c2d')}
# {'BusinessName': 'Jr Farm Meats Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c3a')}
# {'BusinessName': 'The Frog And Orange',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c3e')}
# {'BusinessName': 'BMS Cafe', '_id': ObjectId('65849d5e2481b1c0b7d86c3f')}
# {'BusinessName': 'Crockshard Farm Guest House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c7f')}
# {'BusinessName': 'Gibsons Farm Shop',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c80')}
# {'BusinessName': 'Wingham Country Market',
#  '_id': ObjectId('65849d5e2481b1c0b7d86c89')}
# {'BusinessName': 'Wingham Wildlife Park',
#  '_id': ObjectId('65849d5e2481b1c0b7d86cbe')}
# {'BusinessName': 'Supreme Cuisine', '_id': ObjectId('65849d5e2481b1c0b7d86ceb')}
# {'BusinessName': 'Wingham Recreation Club',
#  '_id': ObjectId('65849d5e2481b1c0b7d86cf7')}
# {'BusinessName': 'Wingham After School & Breakfast Clu',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d17')}
# {'BusinessName': 'The Dog at Wingham',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d18')}
# {'BusinessName': 'Wingham Central Stores',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d19')}
# {'BusinessName': 'The Anchor Inn', '_id': ObjectId('65849d5e2481b1c0b7d86d1a')}
# {'BusinessName': 'Wingham Newsagents',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d1b')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d1c')}
# {'BusinessName': 'Action Sports Nutrition LLP',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d1e')}
# {'BusinessName': 'E T Wilmshurst (Bakery)',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d23')}
# {'BusinessName': 'See-Saw Pre-School',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d24')}
# {'BusinessName': 'Salma', '_id': ObjectId('65849d5e2481b1c0b7d86d26')}
# {'BusinessName': 'Oakfield House', '_id': ObjectId('65849d5e2481b1c0b7d86d2c')}
# {'BusinessName': 'Covert Cafe', '_id': ObjectId('65849d5e2481b1c0b7d86d31')}
# {'BusinessName': 'Dog And Duck Inn',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d33')}
# {'BusinessName': 'Rising Sun', '_id': ObjectId('65849d5e2481b1c0b7d86d34')}
# {'BusinessName': 'Casino Filling Station',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d39')}
# {'BusinessName': 'Preston Village Hall',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d51')}
# {'BusinessName': 'Principals by CH&Co @',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d52')}
# {'BusinessName': 'Home Cuisine Catering Ltd',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d55')}
# {'BusinessName': 'Preston Village Stores',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d6a')}
# {'BusinessName': 'Preston Family Butchers',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d6e')}
# {'BusinessName': 'Half Moon And Seven Stars Public House',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d70')}
# {'BusinessName': 'Coppers Bistro', '_id': ObjectId('65849d5e2481b1c0b7d86d72')}
# {'BusinessName': 'Peacock Events', '_id': ObjectId('65849d5e2481b1c0b7d86d79')}
# {'BusinessName': 'Marleybrook Weddings',
#  '_id': ObjectId('65849d5e2481b1c0b7d86d8a')}
# {'BusinessName': 'Get Prepped', '_id': ObjectId('65849d5e2481b1c0b7d86d93')}

# %%
# Delete all documents where LocalAuthorityName is "Dover"
db.establishments.delete_many({'LocalAuthorityName': "Dover"})

# %%
# Check if any remaining documents include Dover
# set query variables
query = {'LocalAuthorityName': "Dover"}
count = establishments.count_documents(query)

print(f"The number of documents with LocalAuthorityName as \"Dover\": {count}")
# Out:
# The number of documents with LocalAuthorityName as "Dover": 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65849d5e2481b1c0b7d86414'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},[{"$set": 
    {
        "geocode.latitude": {"$toDouble": "$geocode.latitude"}, 
        "geocode.longitude": {"$toDouble": "$geocode.longitude"}
    }
} ])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{"$set": 
    {
        "RatingValue": {"$toInt": "$RatingValue"}
    }
} ])

# %%
# Check that the coordinates and rating value are now numbers
fields = {"BusinessName":1, "geocode":1, "RatingValue":1}
pprint(establishments.find_one({},fields))
# Out:
# {'BusinessName': 'The Pavilion',
#  'RatingValue': 5,
#  '_id': ObjectId('65849d5e2481b1c0b7d86414'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
